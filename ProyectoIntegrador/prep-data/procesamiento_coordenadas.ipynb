# %% [markdown]
# # Manejo de coordenadas y su complejidad
#
# Las coordenadas x, y de cada registro son las características con las cuales el sistema de información ArcGis se alimenta para permitir la visualización. La problemática principal asociada al dataset es, precisamente, errores cometidos durante el proceso de caracterización que afectan las coordenadas y con esto la localización de aproximadamente un ***xxxxx*** de los registros, posicionándolos fuera de antioquia o guardándolos todos en un lugar específico.
#
# Las coordenadas son registradas en el dataset a partir del lugar geográfico en el que fue completada la encuesta, por lo cual, si múltiples personas van por ejemplo a la sede de la alcaldía del municipio para ser encuestadas, sus coordenadas temrinarán representando un clúster alrededor de la sede de la alcaldía en el casco urbano del municipio. Otro factor que interviene es la conexión a internet al momento de completar la encuesta: si al enviarla no hay conexión a internet, la información periste hasta que el dispositivo tenga conexión, sin embargo las coordenadas son propensas a ser corrompidas.
#
# Por esto, la corrección de coordenadas es crucial para una correcta caracterización y diagnóstico de la inclusión a nivel de Población con Discapacidad en el departamento de Antioquia.
#
# A continuación, el plan para abordar esta problemática:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Detección de coordenadas erróneas

# %% [markdown]
# Con el fin de identificar las coordenadas erróneas, es necesario comparar el resultado de la búsqueda con ArcGis con la vereda o el barrio registrado en el dataset.
#
# A través de la API de ArcGis se pueden consultar las veredas con su nombre completo, sin embargo, en el dataset es común encontrarlas con el nombre modificado, incompleto o faltante. Algunos ejemplos que se pueden encontrar en el dataset en la columna "Nombre del Barrio o Vereda (PcD)" son:
#
# - "concepcio" (nombre incompleto)
# - "Calle santander 19" (No es el nombre de un barrio o una vereda, es una calle)
# - "La pava" (Nombre correcto)
#
# En vista de que debemos comparar y encontrar similitudes entre la vereda o barrio registrado en el dataset y el registrado en ArcGis, es necesario un *Procesamiento de nombres de Barrios y Veredas*, dividido en diferentes fases.

# %%
# !pip install unidecode
# !pip install arcgis
# !pip install rapidfuzz
# !pip install pandas
# !pip install openpyxl
# Out:
# Requirement already satisfied: unidecode in c:\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: arcgis in c:\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: pillow in c:\anaconda3\lib\site-packages (from arcgis) (10.3.0)
# Requirement already satisfied: urllib3<3,>=1.26.1 in c:\anaconda3\lib\site-packages (from arcgis) (2.2.2)
# Requirement already satisfied: cachetools in c:\anaconda3\lib\site-packages (from arcgis) (5.3.3)
# Requirement already satisfied: lxml in c:\anaconda3\lib\site-packages (from arcgis) (5.2.1)
# Requirement already satisfied: cryptography in c:\anaconda3\lib\site-packages (from arcgis) (42.0.5)
# Requirement already satisfied: pandas<2.2.0,>=2.0.0 in c:\anaconda3\lib\site-packages (from arcgis) (2.1.4)
# Requirement already satisfied: numpy<2,>=1.21.6 in c:\anaconda3\lib\site-packages (from arcgis) (1.26.4)
# Requirement already satisfied: matplotlib in c:\anaconda3\lib\site-packages (from arcgis) (3.8.4)
# Requirement already satisfied: keyring>=23.3.0 in c:\anaconda3\lib\site-packages (from arcgis) (24.3.1)
# Requirement already satisfied: pylerc in c:\anaconda3\lib\site-packages (from arcgis) (4.0)
# Requirement already satisfied: ujson>=3 in c:\anaconda3\lib\site-packages (from arcgis) (5.10.0)
# Requirement already satisfied: pyshp>=2 in c:\anaconda3\lib\site-packages (from arcgis) (2.3.1)
# Requirement already satisfied: geomet in c:\anaconda3\lib\site-packages (from arcgis) (1.1.0)
# Requirement already satisfied: requests<2.32.0,>=2.30.0 in c:\anaconda3\lib\site-packages (from arcgis) (2.31.0)
# Requirement already satisfied: requests-oauthlib in c:\anaconda3\lib\site-packages (from arcgis) (2.0.0)
# Requirement already satisfied: requests-toolbelt in c:\anaconda3\lib\site-packages (from arcgis) (1.0.0)
# Requirement already satisfied: pyspnego>=0.8.0 in c:\anaconda3\lib\site-packages (from arcgis) (0.11.2)
# Requirement already satisfied: requests-kerberos in c:\anaconda3\lib\site-packages (from arcgis) (0.15.0)
# Requirement already satisfied: requests-gssapi in c:\anaconda3\lib\site-packages (from arcgis) (1.3.0)
# Requirement already satisfied: dask>=2023.3.2 in c:\anaconda3\lib\site-packages (from arcgis) (2024.5.0)
# Requirement already satisfied: matplotlib-inline in c:\anaconda3\lib\site-packages (from arcgis) (0.1.6)
# Requirement already satisfied: pyarrow>=11.0.0 in c:\anaconda3\lib\site-packages (from arcgis) (14.0.2)
# Requirement already satisfied: puremagic<2,>=1.15 in c:\anaconda3\lib\site-packages (from arcgis) (1.28)
# Requirement already satisfied: pywin32>=223 in c:\anaconda3\lib\site-packages (from arcgis) (305.1)
# Requirement already satisfied: truststore>=0.7.0 in c:\anaconda3\lib\site-packages (from arcgis) (0.8.0)
# Requirement already satisfied: click>=8.1 in c:\anaconda3\lib\site-packages (from dask>=2023.3.2->arcgis) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\anaconda3\lib\site-packages (from dask>=2023.3.2->arcgis) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\anaconda3\lib\site-packages (from dask>=2023.3.2->arcgis) (2024.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from dask>=2023.3.2->arcgis) (23.2)
# Requirement already satisfied: partd>=1.2.0 in c:\anaconda3\lib\site-packages (from dask>=2023.3.2->arcgis) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\anaconda3\lib\site-packages (from dask>=2023.3.2->arcgis) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\anaconda3\lib\site-packages (from dask>=2023.3.2->arcgis) (0.12.0)
# Requirement already satisfied: jaraco.classes in c:\anaconda3\lib\site-packages (from keyring>=23.3.0->arcgis) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\anaconda3\lib\site-packages (from keyring>=23.3.0->arcgis) (0.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda3\lib\site-packages (from pandas<2.2.0,>=2.0.0->arcgis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas<2.2.0,>=2.0.0->arcgis) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda3\lib\site-packages (from pandas<2.2.0,>=2.0.0->arcgis) (2023.3)
# Requirement already satisfied: sspilib>=0.1.0 in c:\anaconda3\lib\site-packages (from pyspnego>=0.8.0->arcgis) (0.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests<2.32.0,>=2.30.0->arcgis) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests<2.32.0,>=2.30.0->arcgis) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests<2.32.0,>=2.30.0->arcgis) (2024.7.4)
# Requirement already satisfied: cffi>=1.12 in c:\anaconda3\lib\site-packages (from cryptography->arcgis) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib->arcgis) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib->arcgis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib->arcgis) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->arcgis) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->arcgis) (3.0.9)
# Requirement already satisfied: traitlets in c:\anaconda3\lib\site-packages (from matplotlib-inline->arcgis) (5.14.3)
# Requirement already satisfied: gssapi in c:\anaconda3\lib\site-packages (from requests-gssapi->arcgis) (1.9.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\anaconda3\lib\site-packages (from requests-oauthlib->arcgis) (3.2.2)
# Requirement already satisfied: pycparser in c:\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->arcgis) (2.21)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from click>=8.1->dask>=2023.3.2->arcgis) (0.4.6)
# Requirement already satisfied: locket in c:\anaconda3\lib\site-packages (from partd>=1.2.0->dask>=2023.3.2->arcgis) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.2.0,>=2.0.0->arcgis) (1.16.0)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from gssapi->requests-gssapi->arcgis) (5.1.1)
# Requirement already satisfied: more-itertools in c:\anaconda3\lib\site-packages (from jaraco.classes->keyring>=23.3.0->arcgis) (10.1.0)
# Requirement already satisfied: rapidfuzz in c:\anaconda3\lib\site-packages (3.10.1)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: openpyxl in c:\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# Inicialmente se realiza es proceso de normalización, eliminando las tildes y reescribiendo los nombres en minúsculas, estandarizando así el formato del texto que los métodos van a recibir y haciendo más fácil y precisa la comparación entre dos nombres de localidades.

# %%
# Normalización de nombres de municipios, barrios y veredas en la versión limpia del dataset original

from normalizar_texto import agregar_columnas_normalizadas

#file_path = "clean_pcd_data.csv"
file_path = "sampled_file.csv"

# Llamar al método y almacenar el resultado
dataset_actualizado = agregar_columnas_normalizadas(file_path)

# Verificar las nuevas columnas
print(dataset_actualizado[["Municipio_normalizado", "BarrioVereda_normalizado"]].head())
# Out:
#   Municipio_normalizado BarrioVereda_normalizado
# 0                itagui                 san jose
# 1              rionegro                   capiro
# 2                 anori                guacamaya
# 3              cisneros             calle boyaca
# 4         san francisco                  inojosa

# %% [markdown]
# Adicionalmente, durante la elaboración del presente documento se hizo notable que la presencia de datos "Not a Number" (NaN), especialmente en las columnas sobre las coordenadas (x, y), obstaculizan el procesamiento de los datos. Es por esto que las coordenadas que están vacías o representadas como 0.0 son representadas con las coordenadas del municipio.

# %%
import pandas as pd
import verificacion as ver

# Initialize a counter
processed_count = 0

# Wrapper function to track processed rows
def wrapper_with_count(row):
    global processed_count
    # Check if the row meets the invalid state condition before processing
    invalid_states = [None, "", "0.0", "nan"]
    if pd.isna(row["x"]) or pd.isna(row["y"]) or row["x"] in invalid_states or row["y"] in invalid_states:
        processed_count += 1
    return ver.data_verification(row)

# Apply the function using the wrapper
dataset_actualizado = dataset_actualizado.apply(wrapper_with_count, axis=1)

# Display the total number of processed rows
print(f"Total rows processed: {processed_count}")
# Out:
# ---------------------------------------------------------------------
# Procesando object id 29757
# ---------------------------------------------------------------------
# Procesando object id 36555
# Coordenadas encontradas en el dataset original: nan, nan
# Geocoding municipio: rionegro
# Geocode Results: [{'address': 'Rionegro, Antioquia', 'location': {'x': -75.37413, 'y': 6.15367}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Rionegro', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37413, 'Y': 6.15367, 'DisplayX': -75.37413, 'DisplayY': 6.15367, 'Xmin': -75.39413, 'Xmax': -75.35413, 'Ymin': 6.13367, 'Ymax': 6.17367, 'ExInfo': ''}, 'extent': {'xmin': -75.39413, 'ymin': 6.13367, 'xmax': -75.35413, 'ymax': 6.17367}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.410093381788, 'y': 6.15133503679}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.410093381788, 'Y': 6.15133503679, 'DisplayX': -75.410093381788, 'DisplayY': 6.15133503679, 'Xmin': -75.494093381788, 'Xmax': -75.326093381788, 'Ymin': 6.06733503679, 'Ymax': 6.23533503679, 'ExInfo': ''}, 'extent': {'xmin': -75.494093381788, 'ymin': 6.06733503679, 'xmax': -75.326093381788, 'ymax': 6.23533503679}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.37371, 'y': 6.15515}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37371, 'Y': 6.15515, 'DisplayX': -75.37371, 'DisplayY': 6.15515, 'Xmin': -75.42071, 'Xmax': -75.32671, 'Ymin': 6.10815, 'Ymax': 6.20215, 'ExInfo': ''}, 'extent': {'xmin': -75.42071, 'ymin': 6.10815, 'xmax': -75.32671, 'ymax': 6.20215}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.41667, 'y': 6.16667}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Ri ...
# Coordinates found: -75.37413, 6.15367
# Registro procesado: 36555
# Coordenadas previas: nan, nan
# Nuevas coordenadas: -75.37413, 6.15367
# ---------------------------------------------------------------------
# Procesando object id 13723
# ---------------------------------------------------------------------
# Procesando object id 17800
# ---------------------------------------------------------------------
# Procesando object id 4565
# ---------------------------------------------------------------------
# Procesando object id 33242
# ---------------------------------------------------------------------
# Procesando object id 16509
# ---------------------------------------------------------------------
# Procesando object id 11629
# ---------------------------------------------------------------------
# Procesando object id 31956
# ---------------------------------------------------------------------
# Procesando object id 43501
# ---------------------------------------------------------------------
# Procesando object id 21147
# ---------------------------------------------------------------------
# Procesando object id 46866
# ---------------------------------------------------------------------
# Procesando object id 10598
# ---------------------------------------------------------------------
# Procesando object id 30359
# ---------------------------------------------------------------------
# Procesando object id 48885
# ---------------------------------------------------------------------
# Procesando object id 9766
# ---------------------------------------------------------------------
# Procesando object id 36209
# Coordenadas encontradas en el dataset original: nan, nan
# Geocoding municipio: rionegro
# Geocode Results: [{'address': 'Rionegro, Antioquia', 'location': {'x': -75.37413, 'y': 6.15367}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Rionegro', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37413, 'Y': 6.15367, 'DisplayX': -75.37413, 'DisplayY': 6.15367, 'Xmin': -75.39413, 'Xmax': -75.35413, 'Ymin': 6.13367, 'Ymax': 6.17367, 'ExInfo': ''}, 'extent': {'xmin': -75.39413, 'ymin': 6.13367, 'xmax': -75.35413, 'ymax': 6.17367}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.410093381788, 'y': 6.15133503679}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.410093381788, 'Y': 6.15133503679, 'DisplayX': -75.410093381788, 'DisplayY': 6.15133503679, 'Xmin': -75.494093381788, 'Xmax': -75.326093381788, 'Ymin': 6.06733503679, 'Ymax': 6.23533503679, 'ExInfo': ''}, 'extent': {'xmin': -75.494093381788, 'ymin': 6.06733503679, 'xmax': -75.326093381788, 'ymax': 6.23533503679}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.37371, 'y': 6.15515}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37371, 'Y': 6.15515, 'DisplayX': -75.37371, 'DisplayY': 6.15515, 'Xmin': -75.42071, 'Xmax': -75.32671, 'Ymin': 6.10815, 'Ymax': 6.20215, 'ExInfo': ''}, 'extent': {'xmin': -75.42071, 'ymin': 6.10815, 'xmax': -75.32671, 'ymax': 6.20215}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.41667, 'y': 6.16667}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Ri ...
# Coordinates found: -75.37413, 6.15367
# Registro procesado: 36209
# Coordenadas previas: nan, nan
# Nuevas coordenadas: -75.37413, 6.15367
# ---------------------------------------------------------------------
# Procesando object id 35999
# Coordenadas encontradas en el dataset original: nan, nan
# Geocoding municipio: rionegro
# Geocode Results: [{'address': 'Rionegro, Antioquia', 'location': {'x': -75.37413, 'y': 6.15367}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Rionegro', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37413, 'Y': 6.15367, 'DisplayX': -75.37413, 'DisplayY': 6.15367, 'Xmin': -75.39413, 'Xmax': -75.35413, 'Ymin': 6.13367, 'Ymax': 6.17367, 'ExInfo': ''}, 'extent': {'xmin': -75.39413, 'ymin': 6.13367, 'xmax': -75.35413, 'ymax': 6.17367}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.410093381788, 'y': 6.15133503679}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.410093381788, 'Y': 6.15133503679, 'DisplayX': -75.410093381788, 'DisplayY': 6.15133503679, 'Xmin': -75.494093381788, 'Xmax': -75.326093381788, 'Ymin': 6.06733503679, 'Ymax': 6.23533503679, 'ExInfo': ''}, 'extent': {'xmin': -75.494093381788, 'ymin': 6.06733503679, 'xmax': -75.326093381788, 'ymax': 6.23533503679}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.37371, 'y': 6.15515}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37371, 'Y': 6.15515, 'DisplayX': -75.37371, 'DisplayY': 6.15515, 'Xmin': -75.42071, 'Xmax': -75.32671, 'Ymin': 6.10815, 'Ymax': 6.20215, 'ExInfo': ''}, 'extent': {'xmin': -75.42071, 'ymin': 6.10815, 'xmax': -75.32671, 'ymax': 6.20215}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.41667, 'y': 6.16667}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Ri ...
# Coordinates found: -75.37413, 6.15367
# Registro procesado: 35999
# Coordenadas previas: nan, nan
# Nuevas coordenadas: -75.37413, 6.15367
# ---------------------------------------------------------------------
# Procesando object id 16873
# ---------------------------------------------------------------------
# Procesando object id 10180
# ---------------------------------------------------------------------
# Procesando object id 37304
# ---------------------------------------------------------------------
# Procesando object id 11884
# ---------------------------------------------------------------------
# Procesando object id 36176
# Coordenadas encontradas en el dataset original: nan, nan
# Geocoding municipio: rionegro
# Geocode Results: [{'address': 'Rionegro, Antioquia', 'location': {'x': -75.37413, 'y': 6.15367}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Rionegro', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37413, 'Y': 6.15367, 'DisplayX': -75.37413, 'DisplayY': 6.15367, 'Xmin': -75.39413, 'Xmax': -75.35413, 'Ymin': 6.13367, 'Ymax': 6.17367, 'ExInfo': ''}, 'extent': {'xmin': -75.39413, 'ymin': 6.13367, 'xmax': -75.35413, 'ymax': 6.17367}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.410093381788, 'y': 6.15133503679}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.410093381788, 'Y': 6.15133503679, 'DisplayX': -75.410093381788, 'DisplayY': 6.15133503679, 'Xmin': -75.494093381788, 'Xmax': -75.326093381788, 'Ymin': 6.06733503679, 'Ymax': 6.23533503679, 'ExInfo': ''}, 'extent': {'xmin': -75.494093381788, 'ymin': 6.06733503679, 'xmax': -75.326093381788, 'ymax': 6.23533503679}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.37371, 'y': 6.15515}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Rionegro, Antioquia', 'LongLabel': 'Rionegro, Antioquia, COL', 'ShortLabel': 'Rionegro', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Rionegro', 'Place_addr': 'Rionegro, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.37371, 'Y': 6.15515, 'DisplayX': -75.37371, 'DisplayY': 6.15515, 'Xmin': -75.42071, 'Xmax': -75.32671, 'Ymin': 6.10815, 'Ymax': 6.20215, 'ExInfo': ''}, 'extent': {'xmin': -75.42071, 'ymin': 6.10815, 'xmax': -75.32671, 'ymax': 6.20215}}, {'address': 'Rionegro, Antioquia', 'location': {'x': -75.41667, 'y': 6.16667}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Ri ...
# Coordinates found: -75.37413, 6.15367
# Registro procesado: 36176
# Coordenadas previas: nan, nan
# Nuevas coordenadas: -75.37413, 6.15367
# ---------------------------------------------------------------------
# Procesando object id 30102
# ---------------------------------------------------------------------
# Procesando object id 22141
# ---------------------------------------------------------------------
# Procesando object id 12606
# ---------------------------------------------------------------------
# Procesando object id 38563
# ---------------------------------------------------------------------
# Procesando object id 26811
# ---------------------------------------------------------------------
# Procesando object id 26004
# ---------------------------------------------------------------------
# Procesando object id 33327
# ---------------------------------------------------------------------
# Procesando object id 48533
# ---------------------------------------------------------------------
# Procesando object id 10035
# ---------------------------------------------------------------------
# Procesando object id 25047
# ---------------------------------------------------------------------
# Procesando object id 33659
# ---------------------------------------------------------------------
# Procesando object id 26628
# ---------------------------------------------------------------------
# Procesando object id 12573
# ---------------------------------------------------------------------
# Procesando object id 26421
# ---------------------------------------------------------------------
# Procesando object id 25754
# ---------------------------------------------------------------------
# Procesando object id 28691
# ---------------------------------------------------------------------
# Procesando object id 37732
# ---------------------------------------------------------------------
# Procesando object id 20661
# Coordenadas encontradas en el dataset original: nan, nan
# Geocoding municipio: zaragoza
# Geocode Results: [{'address': 'Zaragoza, Antioquia', 'location': {'x': -74.857880259715, 'y': 7.475101404504}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.857880259715, 'Y': 7.475101404504, 'DisplayX': -74.857880259715, 'DisplayY': 7.475101404504, 'Xmin': -75.103880259715, 'Xmax': -74.611880259715, 'Ymin': 7.229101404504, 'Ymax': 7.721101404504, 'ExInfo': ''}, 'extent': {'xmin': -75.103880259715, 'ymin': 7.229101404504, 'xmax': -74.611880259715, 'ymax': 7.721101404504}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.8693547, 'y': 7.4894514}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Zaragoza', 'City': 'Zaragoza', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.8693547, 'Y': 7.4894514, 'DisplayX': -74.8693547, 'DisplayY': 7.4894514, 'Xmin': -74.8773547, 'Xmax': -74.8613547, 'Ymin': 7.4814514, 'Ymax': 7.4974514, 'ExInfo': ''}, 'extent': {'xmin': -74.8773547, 'ymin': 7.4814514, 'xmax': -74.8613547, 'ymax': 7.4974514}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.86919, 'y': 7.48971}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 13.95, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Zaragoza', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.86919, 'Y': 7.48971, 'DisplayX': -74.86919, 'DisplayY': 7.48971, 'Xmin': -74.89019, 'Xmax': -74.84819, 'Ymin': 7.46871, 'Ymax': 7.51071, 'ExInfo': ''}, 'extent': {'xmin': -74.89019, 'ymin': 7.46871, 'xmax': -74.84819, 'ymax': 7.51071}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.87566, 'y': 7.4829}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status':  ...
# Coordinates found: -74.857880259715, 7.475101404504
# Registro procesado: 20661
# Coordenadas previas: nan, nan
# Nuevas coordenadas: -74.857880259715, 7.475101404504
# ---------------------------------------------------------------------
# Procesando object id 27675
# ---------------------------------------------------------------------
# Procesando object id 34904
# ---------------------------------------------------------------------
# Procesando object id 16861
# ---------------------------------------------------------------------
# Procesando object id 32712
# ---------------------------------------------------------------------
# Procesando object id 9712
# ---------------------------------------------------------------------
# Procesando object id 16252
# ---------------------------------------------------------------------
# Procesando object id 38438
# ---------------------------------------------------------------------
# Procesando object id 4507
# ---------------------------------------------------------------------
# Procesando object id 16519
# ---------------------------------------------------------------------
# Procesando object id 21037
# ---------------------------------------------------------------------
# Procesando object id 48821
# ---------------------------------------------------------------------
# Procesando object id 30952
# ---------------------------------------------------------------------
# Procesando object id 43498
# Coordenadas encontradas en el dataset original: 0.0, 0.0
# Geocoding municipio: puerto nare
# Geocode Results: [{'address': 'Puerto Nare, Antioquia', 'location': {'x': -74.583421, 'y': 6.1867305}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Antioquia', 'LongLabel': 'Puerto Nare, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.09, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Puerto Nare', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.583421, 'Y': 6.1867305, 'DisplayX': -74.583421, 'DisplayY': 6.1867305, 'Xmin': -74.730421, 'Xmax': -74.436421, 'Ymin': 6.0397305, 'Ymax': 6.3337305, 'ExInfo': ''}, 'extent': {'xmin': -74.730421, 'ymin': 6.0397305, 'xmax': -74.436421, 'ymax': 6.3337305}}, {'address': 'Puerto Nare, Nechí, Antioquia', 'location': {'x': -74.81664, 'y': 8.06669}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Nechí, Antioquia', 'LongLabel': 'Puerto Nare, Nechí, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Nechí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 14.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': 'Puerto Nare', 'District': '', 'City': 'Nechí', 'MetroArea': '', 'Subregion': 'Nechí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.81664, 'Y': 8.06669, 'DisplayX': -74.81664, 'DisplayY': 8.06669, 'Xmin': -74.82364, 'Xmax': -74.80964, 'Ymin': 8.05969, 'Ymax': 8.07369, 'ExInfo': ''}, 'extent': {'xmin': -74.82364, 'ymin': 8.05969, 'xmax': -74.80964, 'ymax': 8.07369}}, {'address': 'Puerto Nare, Antioquia', 'location': {'x': -74.5867, 'y': 6.19167}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Antioquia', 'LongLabel': 'Puerto Nare, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Antioquia', 'Phone': '', 'URL': '', 'Rank': 19, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Puerto Nare', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.5867, 'Y': 6.19167, 'DisplayX': -74.5867, 'DisplayY': 6.19167, 'Xmin': -74.7357, 'Xmax': -74.4377, 'Ymin': 6.04267, 'Ymax': 6.34067, 'ExInfo': ''}, 'extent': {'xmin': -74.7357, 'ymin': 6.04267, 'xmax': -74.4377, 'ymax': 6.34067}}, {'address': 'Puerto Nare, Nechí, Antioquia', 'location': {'x': -74.81667, 'y': 8.06667}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Ma ...
# Coordinates found: -74.583421, 6.1867305
# Registro procesado: 43498
# Coordenadas previas: 0.0, 0.0
# Nuevas coordenadas: -74.583421, 6.1867305
# ---------------------------------------------------------------------
# Procesando object id 26398
# ---------------------------------------------------------------------
# Procesando object id 12869
# ---------------------------------------------------------------------
# Procesando object id 18152
# ---------------------------------------------------------------------
# Procesando object id 16630
# ---------------------------------------------------------------------
# Procesando object id 46843
# ---------------------------------------------------------------------
# Procesando object id 38947
# ---------------------------------------------------------------------
# Procesando object id 19183
# ---------------------------------------------------------------------
# Procesando object id 27784
# ---------------------------------------------------------------------
# Procesando object id 21520
# ---------------------------------------------------------------------
# Procesando object id 7183
# ---------------------------------------------------------------------
# Procesando object id 15545
# ---------------------------------------------------------------------
# Procesando object id 11173
# ---------------------------------------------------------------------
# Procesando object id 10017
# ---------------------------------------------------------------------
# Procesando object id 4546
# ---------------------------------------------------------------------
# Procesando object id 41723
# ---------------------------------------------------------------------
# Procesando object id 28352
# ---------------------------------------------------------------------
# Procesando object id 20708
# Coordenadas encontradas en el dataset original: nan, nan
# Geocoding municipio: zaragoza
# Geocode Results: [{'address': 'Zaragoza, Antioquia', 'location': {'x': -74.857880259715, 'y': 7.475101404504}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.857880259715, 'Y': 7.475101404504, 'DisplayX': -74.857880259715, 'DisplayY': 7.475101404504, 'Xmin': -75.103880259715, 'Xmax': -74.611880259715, 'Ymin': 7.229101404504, 'Ymax': 7.721101404504, 'ExInfo': ''}, 'extent': {'xmin': -75.103880259715, 'ymin': 7.229101404504, 'xmax': -74.611880259715, 'ymax': 7.721101404504}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.8693547, 'y': 7.4894514}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Zaragoza', 'City': 'Zaragoza', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.8693547, 'Y': 7.4894514, 'DisplayX': -74.8693547, 'DisplayY': 7.4894514, 'Xmin': -74.8773547, 'Xmax': -74.8613547, 'Ymin': 7.4814514, 'Ymax': 7.4974514, 'ExInfo': ''}, 'extent': {'xmin': -74.8773547, 'ymin': 7.4814514, 'xmax': -74.8613547, 'ymax': 7.4974514}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.86919, 'y': 7.48971}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 13.95, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Zaragoza', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.86919, 'Y': 7.48971, 'DisplayX': -74.86919, 'DisplayY': 7.48971, 'Xmin': -74.89019, 'Xmax': -74.84819, 'Ymin': 7.46871, 'Ymax': 7.51071, 'ExInfo': ''}, 'extent': {'xmin': -74.89019, 'ymin': 7.46871, 'xmax': -74.84819, 'ymax': 7.51071}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.87566, 'y': 7.4829}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status':  ...
# Coordinates found: -74.857880259715, 7.475101404504
# Registro procesado: 20708
# Coordenadas previas: nan, nan
# Nuevas coordenadas: -74.857880259715, 7.475101404504
# ---------------------------------------------------------------------
# Procesando object id 28438
# ---------------------------------------------------------------------
# Procesando object id 38484
# ---------------------------------------------------------------------
# Procesando object id 25233
# ---------------------------------------------------------------------
# Procesando object id 19950
# ---------------------------------------------------------------------
# Procesando object id 29406
# ---------------------------------------------------------------------
# Procesando object id 27099
# ---------------------------------------------------------------------
# Procesando object id 12129
# ---------------------------------------------------------------------
# Procesando object id 49325
# ---------------------------------------------------------------------
# Procesando object id 34926
# ---------------------------------------------------------------------
# Procesando object id 22126
# ---------------------------------------------------------------------
# Procesando object id 7408
# ---------------------------------------------------------------------
# Procesando object id 39241
# ---------------------------------------------------------------------
# Procesando object id 14280
# ---------------------------------------------------------------------
# Procesando object id 15285
# ---------------------------------------------------------------------
# Procesando object id 31957
# ---------------------------------------------------------------------
# Procesando object id 12396
# ---------------------------------------------------------------------
# Procesando object id 33086
# ---------------------------------------------------------------------
# Procesando object id 28164
# ---------------------------------------------------------------------
# Procesando object id 22054
# ---------------------------------------------------------------------
# Procesando object id 30630
# ---------------------------------------------------------------------
# Procesando object id 40939
# ---------------------------------------------------------------------
# Procesando object id 26859
# ---------------------------------------------------------------------
# Procesando object id 3215
# ---------------------------------------------------------------------
# Procesando object id 35886
# ---------------------------------------------------------------------
# Procesando object id 20699
# Coordenadas encontradas en el dataset original: nan, nan
# Geocoding municipio: zaragoza
# Geocode Results: [{'address': 'Zaragoza, Antioquia', 'location': {'x': -74.857880259715, 'y': 7.475101404504}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.857880259715, 'Y': 7.475101404504, 'DisplayX': -74.857880259715, 'DisplayY': 7.475101404504, 'Xmin': -75.103880259715, 'Xmax': -74.611880259715, 'Ymin': 7.229101404504, 'Ymax': 7.721101404504, 'ExInfo': ''}, 'extent': {'xmin': -75.103880259715, 'ymin': 7.229101404504, 'xmax': -74.611880259715, 'ymax': 7.721101404504}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.8693547, 'y': 7.4894514}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Zaragoza', 'City': 'Zaragoza', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.8693547, 'Y': 7.4894514, 'DisplayX': -74.8693547, 'DisplayY': 7.4894514, 'Xmin': -74.8773547, 'Xmax': -74.8613547, 'Ymin': 7.4814514, 'Ymax': 7.4974514, 'ExInfo': ''}, 'extent': {'xmin': -74.8773547, 'ymin': 7.4814514, 'xmax': -74.8613547, 'ymax': 7.4974514}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.86919, 'y': 7.48971}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Zaragoza, Antioquia', 'LongLabel': 'Zaragoza, Antioquia, COL', 'ShortLabel': 'Zaragoza', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Zaragoza', 'Place_addr': 'Zaragoza, Antioquia', 'Phone': '', 'URL': '', 'Rank': 13.95, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Zaragoza', 'MetroArea': '', 'Subregion': 'Zaragoza', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.86919, 'Y': 7.48971, 'DisplayX': -74.86919, 'DisplayY': 7.48971, 'Xmin': -74.89019, 'Xmax': -74.84819, 'Ymin': 7.46871, 'Ymax': 7.51071, 'ExInfo': ''}, 'extent': {'xmin': -74.89019, 'ymin': 7.46871, 'xmax': -74.84819, 'ymax': 7.51071}}, {'address': 'Zaragoza, Antioquia', 'location': {'x': -74.87566, 'y': 7.4829}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status':  ...
# Coordinates found: -74.857880259715, 7.475101404504
# Registro procesado: 20699
# Coordenadas previas: nan, nan
# Nuevas coordenadas: -74.857880259715, 7.475101404504
# ---------------------------------------------------------------------
# Procesando object id 33496
# ---------------------------------------------------------------------
# Procesando object id 15816
# ---------------------------------------------------------------------
# Procesando object id 28792
# ---------------------------------------------------------------------
# Procesando object id 34169
# ---------------------------------------------------------------------
# Procesando object id 48312
# ---------------------------------------------------------------------
# Procesando object id 14036
# ---------------------------------------------------------------------
# Procesando object id 49110
# ---------------------------------------------------------------------
# Procesando object id 27023
# ---------------------------------------------------------------------
# Procesando object id 12087
# ---------------------------------------------------------------------
# Procesando object id 27511
# ---------------------------------------------------------------------
# Procesando object id 41229
# ---------------------------------------------------------------------
# Procesando object id 26773
# ---------------------------------------------------------------------
# Procesando object id 43446
# ---------------------------------------------------------------------
# Procesando object id 11520
# ---------------------------------------------------------------------
# Procesando object id 28041
# ---------------------------------------------------------------------
# Procesando object id 41207
# ---------------------------------------------------------------------
# Procesando object id 45133
# ---------------------------------------------------------------------
# Procesando object id 16526
# ---------------------------------------------------------------------
# Procesando object id 18580
# ---------------------------------------------------------------------
# Procesando object id 47012
# ---------------------------------------------------------------------
# Procesando object id 7430
# ---------------------------------------------------------------------
# Procesando object id 38106
# ---------------------------------------------------------------------
# Procesando object id 10780
# ---------------------------------------------------------------------
# Procesando object id 17838
# ---------------------------------------------------------------------
# Procesando object id 25729
# ---------------------------------------------------------------------
# Procesando object id 10621
# ---------------------------------------------------------------------
# Procesando object id 35873
# ---------------------------------------------------------------------
# Procesando object id 7975
# Coordenadas encontradas en el dataset original: 0.0, 0.0
# Geocoding municipio: amaga
# Geocode Results: [{'address': 'Amagá, Antioquia', 'location': {'x': -75.707819960969, 'y': 6.032850684896}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Amagá, Antioquia', 'LongLabel': 'Amagá, Antioquia, COL', 'ShortLabel': 'Amagá', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Amagá', 'Place_addr': 'Amagá, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Amagá', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.707819960969, 'Y': 6.032850684896, 'DisplayX': -75.707819960969, 'DisplayY': 6.032850684896, 'Xmin': -75.760819960969, 'Xmax': -75.654819960969, 'Ymin': 5.979850684896, 'Ymax': 6.085850684896, 'ExInfo': ''}, 'extent': {'xmin': -75.760819960969, 'ymin': 5.979850684896, 'xmax': -75.654819960969, 'ymax': 6.085850684896}}, {'address': 'Amagá, Antioquia', 'location': {'x': -75.70327, 'y': 6.04126}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Amagá, Antioquia', 'LongLabel': 'Amagá, Antioquia, COL', 'ShortLabel': 'Amagá', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Amagá', 'Place_addr': 'Amagá, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Amagá', 'City': 'Amagá', 'MetroArea': '', 'Subregion': 'Amagá', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.70327, 'Y': 6.04126, 'DisplayX': -75.70327, 'DisplayY': 6.04126, 'Xmin': -75.70927, 'Xmax': -75.69727, 'Ymin': 6.03526, 'Ymax': 6.04726, 'ExInfo': ''}, 'extent': {'xmin': -75.70927, 'ymin': 6.03526, 'xmax': -75.69727, 'ymax': 6.04726}}, {'address': 'Amagá, Antioquia', 'location': {'x': -75.70315, 'y': 6.04001}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Amagá, Antioquia', 'LongLabel': 'Amagá, Antioquia, COL', 'ShortLabel': 'Amagá', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Amagá', 'Place_addr': 'Amagá, Antioquia', 'Phone': '', 'URL': '', 'Rank': 16.41, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Amagá', 'MetroArea': '', 'Subregion': 'Amagá', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.70315, 'Y': 6.04001, 'DisplayX': -75.70315, 'DisplayY': 6.04001, 'Xmin': -75.71815, 'Xmax': -75.68815, 'Ymin': 6.02501, 'Ymax': 6.05501, 'ExInfo': ''}, 'extent': {'xmin': -75.71815, 'ymin': 6.02501, 'xmax': -75.68815, 'ymax': 6.05501}}, {'address': 'Amagá, Antioquia', 'location': {'x': -75.7078, 'y': 6.04027}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Amagá, Antioquia', 'LongLabel': 'Amagá, Antioquia, COL', 'ShortLabel' ...
# Coordinates found: -75.707819960969, 6.032850684896
# Registro procesado: 7975
# Coordenadas previas: 0.0, 0.0
# Nuevas coordenadas: -75.707819960969, 6.032850684896
# ---------------------------------------------------------------------
# Procesando object id 44664
# ---------------------------------------------------------------------
# Procesando object id 45264
# ---------------------------------------------------------------------
# Procesando object id 46860
# ---------------------------------------------------------------------
# Procesando object id 31226
# ---------------------------------------------------------------------
# Procesando object id 30835
# ---------------------------------------------------------------------
# Procesando object id 9724
# ---------------------------------------------------------------------
# Procesando object id 16910
# ---------------------------------------------------------------------
# Procesando object id 28637
# ---------------------------------------------------------------------
# Procesando object id 35900
# ---------------------------------------------------------------------
# Procesando object id 34890
# ---------------------------------------------------------------------
# Procesando object id 34497
# ---------------------------------------------------------------------
# Procesando object id 31992
# ---------------------------------------------------------------------
# Procesando object id 41761
# ---------------------------------------------------------------------
# Procesando object id 26160
# ---------------------------------------------------------------------
# Procesando object id 4628
# ---------------------------------------------------------------------
# Procesando object id 36895
# ---------------------------------------------------------------------
# Procesando object id 16772
# ---------------------------------------------------------------------
# Procesando object id 10489
# ---------------------------------------------------------------------
# Procesando object id 21594
# ---------------------------------------------------------------------
# Procesando object id 36750
# ---------------------------------------------------------------------
# Procesando object id 25758
# ---------------------------------------------------------------------
# Procesando object id 15223
# ---------------------------------------------------------------------
# Procesando object id 34824
# ---------------------------------------------------------------------
# Procesando object id 46923
# ---------------------------------------------------------------------
# Procesando object id 43443
# Coordenadas encontradas en el dataset original: 0.0, 0.0
# Geocoding municipio: caucasia
# Geocode Results: [{'address': 'Caucasia, Antioquia', 'location': {'x': -75.1968546, 'y': 7.9873472}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Caucasia, Antioquia', 'LongLabel': 'Caucasia, Antioquia, COL', 'ShortLabel': 'Caucasia', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Caucasia', 'Place_addr': 'Caucasia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Caucasia', 'City': 'Caucasia', 'MetroArea': '', 'Subregion': 'Caucasia', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.1968546, 'Y': 7.9873472, 'DisplayX': -75.1968546, 'DisplayY': 7.9873472, 'Xmin': -75.2108546, 'Xmax': -75.1828546, 'Ymin': 7.9733472, 'Ymax': 8.0013472, 'ExInfo': ''}, 'extent': {'xmin': -75.2108546, 'ymin': 7.9733472, 'xmax': -75.1828546, 'ymax': 8.0013472}}, {'address': 'Caucasia, Antioquia', 'location': {'x': -75.027360834665, 'y': 7.864559312739}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Caucasia, Antioquia', 'LongLabel': 'Caucasia, Antioquia, COL', 'ShortLabel': 'Caucasia', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Caucasia', 'Place_addr': 'Caucasia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Caucasia', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.027360834665, 'Y': 7.864559312739, 'DisplayX': -75.027360834665, 'DisplayY': 7.864559312739, 'Xmin': -75.291360834665, 'Xmax': -74.763360834665, 'Ymin': 7.600559312739, 'Ymax': 8.128559312739, 'ExInfo': ''}, 'extent': {'xmin': -75.291360834665, 'ymin': 7.600559312739, 'xmax': -74.763360834665, 'ymax': 8.128559312739}}, {'address': 'Caucasia, Antioquia', 'location': {'x': -75.19349, 'y': 7.98654}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Caucasia, Antioquia', 'LongLabel': 'Caucasia, Antioquia, COL', 'ShortLabel': 'Caucasia', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Caucasia', 'Place_addr': 'Caucasia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 13.52, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Caucasia', 'MetroArea': '', 'Subregion': 'Caucasia', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.19349, 'Y': 7.98654, 'DisplayX': -75.19349, 'DisplayY': 7.98654, 'Xmin': -75.22549, 'Xmax': -75.16149, 'Ymin': 7.95454, 'Ymax': 8.01854, 'ExInfo': ''}, 'extent': {'xmin': -75.22549, 'ymin': 7.95454, 'xmax': -75.16149, 'ymax': 8.01854}}, {'address': 'Caucasia, Antioquia', 'location': {'x': -75.02858, 'y': 7.86695}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status':  ...
# Coordinates found: -75.1968546, 7.9873472
# Registro procesado: 43443
# Coordenadas previas: 0.0, 0.0
# Nuevas coordenadas: -75.1968546, 7.9873472
# ---------------------------------------------------------------------
# Procesando object id 20947
# Total rows processed: 10

# %% [markdown]
# Habiendo normalizado los nombres de las veredas y municipios y habiendo rellenado las coordenadas no válidas, el procesamiento de texto se hace mucho más sencillo. A continuación, se evalúan cuáles registros de la columna "Zona de residencia (PcD)" corresponden a la Zona Rural de su municipio y cuáles a la Zona Urbana. Esto porque la Zona Urbana en lugar de estar dividida en veredas, está dividida en barrios, y dichos barrios (así como zonas descritas a partir de nombres de calles o direcciones) no siempre se encuentran disponibles en los mapas de ArcGis para todos los municipios. El procesamiento de direcciones y barrios de las zonas urbanas está destinado para entregas futuras.

# %%
import coordenadas_arcgis as ag 

df_urbano, df_rural = ag.dividir_por_zona(dataset_actualizado)

# %% [markdown]
# ## Procesamiento de coordenadas en la zona rural
#
# ### Obtención de coordenadas de las veredas

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Con el fin de conservar los datos más exactos posibles, se verifica que las coordenadas registradas para cada registro sean las de las veredas especificadas. Si la vereda encontrada con las coordenadas no coincide con la registrada en la encuesta, se intentan registrar las coordenadas de la veredea especificada en la encuesta. Si no se puede encontrar la vereda, se registra el nombre del municipio al que pertenece.

# %%
import normalizar_texto as norm
import coincidencia_difusa as cd


def procesar_coordenadas_vereda(row):
    
    vereda_dataset = row["BarrioVereda_normalizado"]
    id = row["ObjectID"]
    print("---------------------------------------------------------------------")
    print(f"Procesando object id {id}. \nVereda normalizada: {vereda_dataset}")

    # Tomar las coordenadas y verificar si están en la vereda
    x = row["x"]
    y = row["y"]
    vereda = ag.query_vereda(x, y)

    # No se encontró una vereda asociada a esas coordenadas
    if vereda == None:
        # Buscar coordenadas de la vereda registrada en el dataset dado el nombre
        print("No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...")
        x, y = ag.query_vereda_coordinates(vereda_dataset)

        # Si no se encuentra, se ponen las coordenadas del municipio
        if x is None or y is None:
            # Poner la del municipio***
            id = row["ObjectID"]
            municipio = row["Municipio_normalizado"]
            row["x"], row["y"] = ag.geocode_municipio(municipio)
            print(f"No se pudo encontrar la vereda {vereda_dataset} del registro {id} en el mapa de veredas. \nAsignando coordenadas del municipio {municipio}.")
        
        else:
            print(f"Coordenadas encontradas para {vereda_dataset}: {x}, {y}")
            row["x"] = x
            row["y"] = y
    # Se encontró una vereda asociada a esas coordenadas
    else:
        
        # Normalización de la vereda obtenida desde ArcGis
        vereda_norm = norm.normalizar_texto(vereda)
        print(f"Se encontró una vereda asociada a estas coordenadas: {vereda_norm}. Comparando con la vereda registrada...")

        # Comparar vereda registrada en la encuesta y vereda obtenida en la consulta
        vereda_original = row["BarrioVereda_normalizado"]
        similitud = cd.comparar_frases(vereda_norm, vereda_original, 65)

        print(f"Existe similitud entre {vereda_original} y {vereda_norm}?: {similitud}")

        # Si la similitud es menor al 65% se toma el nombre de la vereda registrada originalmente y se busca en el mapa de veredas
        if not similitud:
            print(f"Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...")
            x, y = ag.query_vereda_coordinates(vereda_dataset)
            
            # Se intenta encontrar la vereda del dataset en el mapa de veredas
            if x is None or y is None:
                # Poner las coordenadas del municipio
                municipio = row["Municipio_normalizado"]
                row["x"], row["y"] = ag.geocode_municipio(municipio)
                print(f"No se pudo encontrar la vereda {vereda_dataset} en el mapa de veredas. \nAsignando coordenadas del municipio {municipio}.")
            else:
                print(f"Coordenadas encontradas para {vereda_dataset}: {x}, {y}")
                row["x"] = x
                row["y"] = y
            
df_rural.apply(procesar_coordenadas_vereda, axis=1)
# Out:
# ---------------------------------------------------------------------
# Procesando object id 36555.
# Vereda normalizada: capiro
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para capiro: -75.40202303265198, 6.080454076376787
# ---------------------------------------------------------------------
# Procesando object id 4565.
# Vereda normalizada: inojosa
# Se encontró una vereda asociada a estas coordenadas: pocitos. Comparando con la vereda registrada...
# Existe similitud entre inojosa y pocitos?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: san francisco
# Geocode Results: [{'address': 'San Francisco, Antioquia', 'location': {'x': -74.976944221047, 'y': 5.879794408084}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'San Francisco, Antioquia', 'LongLabel': 'San Francisco, Antioquia, COL', 'ShortLabel': 'San Francisco', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'San Francisco', 'Place_addr': 'San Francisco, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'San Francisco', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.976944221047, 'Y': 5.879794408084, 'DisplayX': -74.976944221047, 'DisplayY': 5.879794408084, 'Xmin': -75.106944221047, 'Xmax': -74.846944221047, 'Ymin': 5.749794408084, 'Ymax': 6.009794408084, 'ExInfo': ''}, 'extent': {'xmin': -75.106944221047, 'ymin': 5.749794408084, 'xmax': -74.846944221047, 'ymax': 6.009794408084}}, {'address': 'San Francisco, Antioquia', 'location': {'x': -75.10164, 'y': 5.96485}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'San Francisco, Antioquia', 'LongLabel': 'San Francisco, Antioquia, COL', 'ShortLabel': 'San Francisco', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'San Francisco', 'Place_addr': 'San Francisco, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'San Francisco', 'City': 'San Francisco', 'MetroArea': '', 'Subregion': 'San Francisco', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.10164, 'Y': 5.96485, 'DisplayX': -75.10164, 'DisplayY': 5.96485, 'Xmin': -75.10464, 'Xmax': -75.09864, 'Ymin': 5.96185, 'Ymax': 5.96785, 'ExInfo': ''}, 'extent': {'xmin': -75.10464, 'ymin': 5.96185, 'xmax': -75.09864, 'ymax': 5.96785}}, {'address': 'San Francisco, Briceño, Antioquia', 'location': {'x': -75.5181793, 'y': 7.1066547}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'San Francisco, Briceño, Antioquia', 'LongLabel': 'San Francisco, Briceño, Antioquia, COL', 'ShortLabel': 'San Francisco', 'Addr_type': 'Locality', 'Type': 'Neighborhood', 'PlaceName': 'San Francisco', 'Place_addr': 'San Francisco, Briceño, Antioquia', 'Phone': '', 'URL': '', 'Rank': 13.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': 'San Francisco', 'District': '', 'City': 'Briceño', 'MetroArea': '', 'Subregion': 'Briceño', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.5181793, 'Y': 7.1066547, 'DisplayX': -75.5181793, 'DisplayY': 7.1066547, 'Xmin': -75.5391793, 'Xmax': -75.4971793, 'Ymin': 7.0856547, 'Ymax': 7.1276547, 'ExInfo': ''}, 'extent': {'xmin': -75.5391793, 'ymin': 7.0856547, 'xmax': -75.4 ...
# Coordinates found: -74.976944221047, 5.879794408084
# No se pudo encontrar la vereda inojosa en el mapa de veredas.
# Asignando coordenadas del municipio san francisco.
# ---------------------------------------------------------------------
# Procesando object id 31956.
# Vereda normalizada: palmichal
# Se encontró una vereda asociada a estas coordenadas: palmichal. Comparando con la vereda registrada...
# Existe similitud entre palmichal y palmichal?: True
# ---------------------------------------------------------------------
# Procesando object id 43501.
# Vereda normalizada: 20 enero corregimiento sierra
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: puerto nare
# Geocode Results: [{'address': 'Puerto Nare, Antioquia', 'location': {'x': -74.583421, 'y': 6.1867305}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Antioquia', 'LongLabel': 'Puerto Nare, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.09, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Puerto Nare', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.583421, 'Y': 6.1867305, 'DisplayX': -74.583421, 'DisplayY': 6.1867305, 'Xmin': -74.730421, 'Xmax': -74.436421, 'Ymin': 6.0397305, 'Ymax': 6.3337305, 'ExInfo': ''}, 'extent': {'xmin': -74.730421, 'ymin': 6.0397305, 'xmax': -74.436421, 'ymax': 6.3337305}}, {'address': 'Puerto Nare, Nechí, Antioquia', 'location': {'x': -74.81664, 'y': 8.06669}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Nechí, Antioquia', 'LongLabel': 'Puerto Nare, Nechí, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Nechí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 14.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': 'Puerto Nare', 'District': '', 'City': 'Nechí', 'MetroArea': '', 'Subregion': 'Nechí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.81664, 'Y': 8.06669, 'DisplayX': -74.81664, 'DisplayY': 8.06669, 'Xmin': -74.82364, 'Xmax': -74.80964, 'Ymin': 8.05969, 'Ymax': 8.07369, 'ExInfo': ''}, 'extent': {'xmin': -74.82364, 'ymin': 8.05969, 'xmax': -74.80964, 'ymax': 8.07369}}, {'address': 'Puerto Nare, Antioquia', 'location': {'x': -74.5867, 'y': 6.19167}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Antioquia', 'LongLabel': 'Puerto Nare, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Antioquia', 'Phone': '', 'URL': '', 'Rank': 19, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Puerto Nare', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.5867, 'Y': 6.19167, 'DisplayX': -74.5867, 'DisplayY': 6.19167, 'Xmin': -74.7357, 'Xmax': -74.4377, 'Ymin': 6.04267, 'Ymax': 6.34067, 'ExInfo': ''}, 'extent': {'xmin': -74.7357, 'ymin': 6.04267, 'xmax': -74.4377, 'ymax': 6.34067}}, {'address': 'Puerto Nare, Nechí, Antioquia', 'location': {'x': -74.81667, 'y': 8.06667}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Ma ...
# Coordinates found: -74.583421, 6.1867305
# No se pudo encontrar la vereda 20 enero corregimiento sierra del registro 43501 en el mapa de veredas.
# Asignando coordenadas del municipio puerto nare.
# ---------------------------------------------------------------------
# Procesando object id 30359.
# Vereda normalizada: bajo del oso
# Se encontró una vereda asociada a estas coordenadas: bajo del oso. Comparando con la vereda registrada...
# Existe similitud entre bajo del oso y bajo del oso?: True
# ---------------------------------------------------------------------
# Procesando object id 48885.
# Vereda normalizada: corregimiento zapata
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: necocli
# Geocode Results: [{'address': 'Necoclí, Antioquia', 'location': {'x': -76.78497, 'y': 8.42321}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia', 'LongLabel': 'Necoclí, Antioquia, COL', 'ShortLabel': 'Necoclí', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Necoclí', 'Place_addr': 'Necoclí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Necoclí', 'City': 'Necoclí', 'MetroArea': '', 'Subregion': 'Necoclí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.78497, 'Y': 8.42321, 'DisplayX': -76.78497, 'DisplayY': 8.42321, 'Xmin': -76.79297, 'Xmax': -76.77697, 'Ymin': 8.41521, 'Ymax': 8.43121, 'ExInfo': ''}, 'extent': {'xmin': -76.79297, 'ymin': 8.41521, 'xmax': -76.77697, 'ymax': 8.43121}}, {'address': 'Necoclí, Antioquia', 'location': {'x': -76.674612805448, 'y': 8.492832821283}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia', 'LongLabel': 'Necoclí, Antioquia, COL', 'ShortLabel': 'Necoclí', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Necoclí', 'Place_addr': 'Necoclí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Necoclí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.674612805448, 'Y': 8.492832821283, 'DisplayX': -76.674612805448, 'DisplayY': 8.492832821283, 'Xmin': -76.918612805448, 'Xmax': -76.430612805448, 'Ymin': 8.248832821283, 'Ymax': 8.736832821283, 'ExInfo': ''}, 'extent': {'xmin': -76.918612805448, 'ymin': 8.248832821283, 'xmax': -76.430612805448, 'ymax': 8.736832821283}}, {'address': 'Necoclí, Antioquia', 'location': {'x': -76.78926, 'y': 8.42627}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia', 'LongLabel': 'Necoclí, Antioquia, COL', 'ShortLabel': 'Necoclí', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Necoclí', 'Place_addr': 'Necoclí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 16.48, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Necoclí', 'MetroArea': '', 'Subregion': 'Necoclí', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.78926, 'Y': 8.42627, 'DisplayX': -76.78926, 'DisplayY': 8.42627, 'Xmin': -76.80426, 'Xmax': -76.77426, 'Ymin': 8.41127, 'Ymax': 8.44127, 'ExInfo': ''}, 'extent': {'xmin': -76.80426, 'ymin': 8.41127, 'xmax': -76.77426, 'ymax': 8.44127}}, {'address': 'Necoclí, Antioquia', 'location': {'x': -76.77109, 'y': 8.42958}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia' ...
# Coordinates found: -76.78497, 8.42321
# No se pudo encontrar la vereda corregimiento zapata del registro 48885 en el mapa de veredas.
# Asignando coordenadas del municipio necocli.
# ---------------------------------------------------------------------
# Procesando object id 9766.
# Vereda normalizada: pomar
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para pomar: -75.71741903101879, 6.558799306603344
# ---------------------------------------------------------------------
# Procesando object id 36209.
# Vereda normalizada: abreito
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para abreito: -75.41160702851703, 6.1706684402747936
# ---------------------------------------------------------------------
# Procesando object id 35999.
# Vereda normalizada: rio abajo
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para rio abajo: -75.34523926538803, 6.221915468332411
# ---------------------------------------------------------------------
# Procesando object id 37304.
# Vereda normalizada: ajizal
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para ajizal: -75.60692536637023, 6.193790011712423
# ---------------------------------------------------------------------
# Procesando object id 33327.
# Vereda normalizada: mejia
# Se encontró una vereda asociada a estas coordenadas: mejia. Comparando con la vereda registrada...
# Existe similitud entre mejia y mejia?: True
# ---------------------------------------------------------------------
# Procesando object id 48533.
# Vereda normalizada: vda moraditas
# Se encontró una vereda asociada a estas coordenadas: chaparral. Comparando con la vereda registrada...
# Existe similitud entre vda moraditas y chaparral?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: santa fe antioquia
# Geocode Results: [{'address': 'Santa Fe Antioquia', 'location': {'x': -75.826428035085, 'y': 6.557772275953}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'M', 'Score': 100, 'Match_addr': 'Santa Fe Antioquia', 'LongLabel': 'Santa Fe Antioquia, Carrera 9 16-36, Santa Fe de Antioquia, Antioquia, COL', 'ShortLabel': 'Santa Fe Antioquia', 'Addr_type': 'POI', 'Type': 'Grocery', 'PlaceName': 'Santa Fe Antioquia', 'Place_addr': 'Carrera 9 16-36, Santa Fe de Antioquia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 19, 'AddBldg': '', 'AddNum': '16-36', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': 'Carrera', 'StName': '9', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': 'Carrera 9 16-36', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Santa Fe', 'City': 'Santa Fe de Antioquia', 'MetroArea': '', 'Subregion': 'Santa Fe de Antioquia', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '057050', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.826428035085, 'Y': 6.557772275953, 'DisplayX': -75.82763, 'DisplayY': 6.55853, 'Xmin': -75.83263, 'Xmax': -75.82263, 'Ymin': 6.55353, 'Ymax': 6.56353, 'ExInfo': ''}, 'extent': {'xmin': -75.83263, 'ymin': 6.55353, 'xmax': -75.82263, 'ymax': 6.56353}}, {'address': 'Santa Fe de Antioquia, Antioquia', 'location': {'x': -75.899000835243, 'y': 6.529095178204}, 'score': 99.59, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 99.59, 'Match_addr': 'Santa Fe de Antioquia, Antioquia', 'LongLabel': 'Santa Fe de Antioquia, Antioquia, COL', 'ShortLabel': 'Santa Fe de Antioquia', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Santa Fe de Antioquia', 'Place_addr': 'Santa Fe de Antioquia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Santa Fe de Antioquia', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.899000835243, 'Y': 6.529095178204, 'DisplayX': -75.899000835243, 'DisplayY': 6.529095178204, 'Xmin': -76.032000835243, 'Xmax': -75.766000835243, 'Ymin': 6.396095178204, 'Ymax': 6.662095178204, 'ExInfo': ''}, 'extent': {'xmin': -76.032000835243, 'ymin': 6.396095178204, 'xmax': -75.766000835243, 'ymax': 6.662095178204}}, {'address': 'Santa Fe de Antioquia, Santafé de Antioquia, Antioquia', 'location': {'x': -75.82806, 'y': 6.55687}, 'score': 99.59, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 99.59, 'Match_addr': 'Santa Fe de Antioquia, Santafé de Antioquia, Antioquia', 'LongLabel': 'Santa Fe de Antioquia, Santafé de Antioquia, Antioquia, COL', 'ShortLabel': 'Santa Fe de Antioquia', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Santa Fe de Antioquia', 'Place_addr': 'Antioquia, Santafé de Antioquia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 15.96, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Antioquia', 'MetroArea': '', 'Subregion': 'Santafé de Antioquia', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia' ...
# Coordinates found: -75.826428035085, 6.557772275953
# No se pudo encontrar la vereda vda moraditas en el mapa de veredas.
# Asignando coordenadas del municipio santa fe antioquia.
# ---------------------------------------------------------------------
# Procesando object id 12573.
# Vereda normalizada: guajira abajo
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para guajira abajo: -75.26381542690328, 6.933462753130406
# ---------------------------------------------------------------------
# Procesando object id 25754.
# Vereda normalizada: corregimiento pueblo nuevo
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: necocli
# Geocode Results: [{'address': 'Necoclí, Antioquia', 'location': {'x': -76.78497, 'y': 8.42321}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia', 'LongLabel': 'Necoclí, Antioquia, COL', 'ShortLabel': 'Necoclí', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Necoclí', 'Place_addr': 'Necoclí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Necoclí', 'City': 'Necoclí', 'MetroArea': '', 'Subregion': 'Necoclí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.78497, 'Y': 8.42321, 'DisplayX': -76.78497, 'DisplayY': 8.42321, 'Xmin': -76.79297, 'Xmax': -76.77697, 'Ymin': 8.41521, 'Ymax': 8.43121, 'ExInfo': ''}, 'extent': {'xmin': -76.79297, 'ymin': 8.41521, 'xmax': -76.77697, 'ymax': 8.43121}}, {'address': 'Necoclí, Antioquia', 'location': {'x': -76.674612805448, 'y': 8.492832821283}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia', 'LongLabel': 'Necoclí, Antioquia, COL', 'ShortLabel': 'Necoclí', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Necoclí', 'Place_addr': 'Necoclí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Necoclí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.674612805448, 'Y': 8.492832821283, 'DisplayX': -76.674612805448, 'DisplayY': 8.492832821283, 'Xmin': -76.918612805448, 'Xmax': -76.430612805448, 'Ymin': 8.248832821283, 'Ymax': 8.736832821283, 'ExInfo': ''}, 'extent': {'xmin': -76.918612805448, 'ymin': 8.248832821283, 'xmax': -76.430612805448, 'ymax': 8.736832821283}}, {'address': 'Necoclí, Antioquia', 'location': {'x': -76.78926, 'y': 8.42627}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia', 'LongLabel': 'Necoclí, Antioquia, COL', 'ShortLabel': 'Necoclí', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Necoclí', 'Place_addr': 'Necoclí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 16.48, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Necoclí', 'MetroArea': '', 'Subregion': 'Necoclí', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.78926, 'Y': 8.42627, 'DisplayX': -76.78926, 'DisplayY': 8.42627, 'Xmin': -76.80426, 'Xmax': -76.77426, 'Ymin': 8.41127, 'Ymax': 8.44127, 'ExInfo': ''}, 'extent': {'xmin': -76.80426, 'ymin': 8.41127, 'xmax': -76.77426, 'ymax': 8.44127}}, {'address': 'Necoclí, Antioquia', 'location': {'x': -76.77109, 'y': 8.42958}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Necoclí, Antioquia' ...
# Coordinates found: -76.78497, 8.42321
# No se pudo encontrar la vereda corregimiento pueblo nuevo del registro 25754 en el mapa de veredas.
# Asignando coordenadas del municipio necocli.
# ---------------------------------------------------------------------
# Procesando object id 28691.
# Vereda normalizada: jardin
# Se encontró una vereda asociada a estas coordenadas: asturias. Comparando con la vereda registrada...
# Existe similitud entre jardin y asturias?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para jardin: -74.89907451707526, 6.630906424920975
# ---------------------------------------------------------------------
# Procesando object id 21037.
# Vereda normalizada: bejuquillo
# Se encontró una vereda asociada a estas coordenadas: bejuquillo. Comparando con la vereda registrada...
# Existe similitud entre bejuquillo y bejuquillo?: True
# ---------------------------------------------------------------------
# Procesando object id 30952.
# Vereda normalizada: arenal
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para arenal: -76.79586744933252, 6.514331892261528
# ---------------------------------------------------------------------
# Procesando object id 43498.
# Vereda normalizada: correjimiento sierra sierra morena
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: puerto nare
# Geocode Results: [{'address': 'Puerto Nare, Antioquia', 'location': {'x': -74.583421, 'y': 6.1867305}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Antioquia', 'LongLabel': 'Puerto Nare, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.09, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Puerto Nare', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.583421, 'Y': 6.1867305, 'DisplayX': -74.583421, 'DisplayY': 6.1867305, 'Xmin': -74.730421, 'Xmax': -74.436421, 'Ymin': 6.0397305, 'Ymax': 6.3337305, 'ExInfo': ''}, 'extent': {'xmin': -74.730421, 'ymin': 6.0397305, 'xmax': -74.436421, 'ymax': 6.3337305}}, {'address': 'Puerto Nare, Nechí, Antioquia', 'location': {'x': -74.81664, 'y': 8.06669}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Nechí, Antioquia', 'LongLabel': 'Puerto Nare, Nechí, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Nechí, Antioquia', 'Phone': '', 'URL': '', 'Rank': 14.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': 'Puerto Nare', 'District': '', 'City': 'Nechí', 'MetroArea': '', 'Subregion': 'Nechí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.81664, 'Y': 8.06669, 'DisplayX': -74.81664, 'DisplayY': 8.06669, 'Xmin': -74.82364, 'Xmax': -74.80964, 'Ymin': 8.05969, 'Ymax': 8.07369, 'ExInfo': ''}, 'extent': {'xmin': -74.82364, 'ymin': 8.05969, 'xmax': -74.80964, 'ymax': 8.07369}}, {'address': 'Puerto Nare, Antioquia', 'location': {'x': -74.5867, 'y': 6.19167}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Nare, Antioquia', 'LongLabel': 'Puerto Nare, Antioquia, COL', 'ShortLabel': 'Puerto Nare', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Puerto Nare', 'Place_addr': 'Puerto Nare, Antioquia', 'Phone': '', 'URL': '', 'Rank': 19, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Puerto Nare', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.5867, 'Y': 6.19167, 'DisplayX': -74.5867, 'DisplayY': 6.19167, 'Xmin': -74.7357, 'Xmax': -74.4377, 'Ymin': 6.04267, 'Ymax': 6.34067, 'ExInfo': ''}, 'extent': {'xmin': -74.7357, 'ymin': 6.04267, 'xmax': -74.4377, 'ymax': 6.34067}}, {'address': 'Puerto Nare, Nechí, Antioquia', 'location': {'x': -74.81667, 'y': 8.06667}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Ma ...
# Coordinates found: -74.583421, 6.1867305
# No se pudo encontrar la vereda correjimiento sierra sierra morena del registro 43498 en el mapa de veredas.
# Asignando coordenadas del municipio puerto nare.
# ---------------------------------------------------------------------
# Procesando object id 26398.
# Vereda normalizada: san lazaro
# Se encontró una vereda asociada a estas coordenadas: lazaro. Comparando con la vereda registrada...
# Existe similitud entre san lazaro y lazaro?: True
# ---------------------------------------------------------------------
# Procesando object id 18152.
# Vereda normalizada: aguadita san pascual
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: canasgordas
# Geocode Results: [{'address': 'Cañasgordas, Antioquia', 'location': {'x': -76.026445371395, 'y': 6.815283565835}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Cañasgordas, Antioquia', 'LongLabel': 'Cañasgordas, Antioquia, COL', 'ShortLabel': 'Cañasgordas', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Cañasgordas', 'Place_addr': 'Cañasgordas, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Cañasgordas', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.026445371395, 'Y': 6.815283565835, 'DisplayX': -76.026445371395, 'DisplayY': 6.815283565835, 'Xmin': -76.153445371395, 'Xmax': -75.899445371395, 'Ymin': 6.688283565835, 'Ymax': 6.942283565835, 'ExInfo': ''}, 'extent': {'xmin': -76.153445371395, 'ymin': 6.688283565835, 'xmax': -75.899445371395, 'ymax': 6.942283565835}}, {'address': 'Cañasgordas, Antioquia', 'location': {'x': -76.02578, 'y': 6.7494}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Cañasgordas, Antioquia', 'LongLabel': 'Cañasgordas, Antioquia, COL', 'ShortLabel': 'Cañasgordas', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Cañasgordas', 'Place_addr': 'Cañasgordas, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Cañasgordas', 'City': 'Cañasgordas', 'MetroArea': '', 'Subregion': 'Cañasgordas', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.02578, 'Y': 6.7494, 'DisplayX': -76.02578, 'DisplayY': 6.7494, 'Xmin': -76.03578, 'Xmax': -76.01578, 'Ymin': 6.7394, 'Ymax': 6.7594, 'ExInfo': ''}, 'extent': {'xmin': -76.03578, 'ymin': 6.7394, 'xmax': -76.01578, 'ymax': 6.7594}}, {'address': 'Cañasgordas, Antioquia', 'location': {'x': -76.02539, 'y': 6.74989}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Cañasgordas, Antioquia', 'LongLabel': 'Cañasgordas, Antioquia, COL', 'ShortLabel': 'Cañasgordas', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Cañasgordas', 'Place_addr': 'Cañasgordas, Antioquia', 'Phone': '', 'URL': '', 'Rank': 16.34, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Cañasgordas', 'MetroArea': '', 'Subregion': 'Cañasgordas', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.02539, 'Y': 6.74989, 'DisplayX': -76.02539, 'DisplayY': 6.74989, 'Xmin': -76.04139, 'Xmax': -76.00939, 'Ymin': 6.73389, 'Ymax': 6.76589, 'ExInfo': ''}, 'extent': {'xmin': -76.04139, 'ymin': 6.73389, 'xmax': -76.00939, 'ymax': 6.76589}}, {'address': 'Cañasgordas, Antioquia', 'location': {'x': -76.03954, 'y': 6.80951}, 'score': 100, 'attr ...
# Coordinates found: -76.026445371395, 6.815283565835
# No se pudo encontrar la vereda aguadita san pascual del registro 18152 en el mapa de veredas.
# Asignando coordenadas del municipio canasgordas.
# ---------------------------------------------------------------------
# Procesando object id 46843.
# Vereda normalizada: cabanas
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: puerto berrio
# Geocode Results: [{'address': 'Puerto Berrío, Antioquia', 'location': {'x': -74.528314174582, 'y': 6.481590028649}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Berrío, Antioquia', 'LongLabel': 'Puerto Berrío, Antioquia, COL', 'ShortLabel': 'Puerto Berrío', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Puerto Berrío', 'Place_addr': 'Puerto Berrío, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Puerto Berrío', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.528314174582, 'Y': 6.481590028649, 'DisplayX': -74.528314174582, 'DisplayY': 6.481590028649, 'Xmin': -74.751314174582, 'Xmax': -74.305314174582, 'Ymin': 6.258590028649, 'Ymax': 6.704590028649, 'ExInfo': ''}, 'extent': {'xmin': -74.751314174582, 'ymin': 6.258590028649, 'xmax': -74.305314174582, 'ymax': 6.704590028649}}, {'address': 'Puerto Berrío, Antioquia', 'location': {'x': -74.4026682, 'y': 6.490949}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Berrío, Antioquia', 'LongLabel': 'Puerto Berrío, Antioquia, COL', 'ShortLabel': 'Puerto Berrío', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Puerto Berrío', 'Place_addr': 'Puerto Berrío, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Puerto Berrío', 'City': 'Puerto Berrío', 'MetroArea': '', 'Subregion': 'Puerto Berrío', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.4026682, 'Y': 6.490949, 'DisplayX': -74.4026682, 'DisplayY': 6.490949, 'Xmin': -74.4106682, 'Xmax': -74.3946682, 'Ymin': 6.482949, 'Ymax': 6.498949, 'ExInfo': ''}, 'extent': {'xmin': -74.4106682, 'ymin': 6.482949, 'xmax': -74.3946682, 'ymax': 6.498949}}, {'address': 'Puerto Berrío, Antioquia', 'location': {'x': -74.40326, 'y': 6.49156}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Puerto Berrío, Antioquia', 'LongLabel': 'Puerto Berrío, Antioquia, COL', 'ShortLabel': 'Puerto Berrío', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Puerto Berrío', 'Place_addr': 'Puerto Berrío, Antioquia', 'Phone': '', 'URL': '', 'Rank': 13.61, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Puerto Berrío', 'MetroArea': '', 'Subregion': 'Puerto Berrío', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -74.40326, 'Y': 6.49156, 'DisplayX': -74.40326, 'DisplayY': 6.49156, 'Xmin': -74.43326, 'Xmax': -74.37326, 'Ymin': 6.46156, 'Ymax': 6.52156, 'ExInfo': ''}, 'extent': {'xmin': -74.43326, 'ymin': 6.46156, 'xmax': -74.37326, 'ymax': 6.52156}}, {'address': 'Puerto Berrí ...
# Coordinates found: -74.528314174582, 6.481590028649
# No se pudo encontrar la vereda cabanas del registro 46843 en el mapa de veredas.
# Asignando coordenadas del municipio puerto berrio.
# ---------------------------------------------------------------------
# Procesando object id 21520.
# Vereda normalizada: corregimiento palomar
# Se encontró una vereda asociada a estas coordenadas: palomar. Comparando con la vereda registrada...
# Existe similitud entre corregimiento palomar y palomar?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: caucasia
# Geocode Results: [{'address': 'Caucasia, Antioquia', 'location': {'x': -75.1968546, 'y': 7.9873472}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Caucasia, Antioquia', 'LongLabel': 'Caucasia, Antioquia, COL', 'ShortLabel': 'Caucasia', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Caucasia', 'Place_addr': 'Caucasia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Caucasia', 'City': 'Caucasia', 'MetroArea': '', 'Subregion': 'Caucasia', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.1968546, 'Y': 7.9873472, 'DisplayX': -75.1968546, 'DisplayY': 7.9873472, 'Xmin': -75.2108546, 'Xmax': -75.1828546, 'Ymin': 7.9733472, 'Ymax': 8.0013472, 'ExInfo': ''}, 'extent': {'xmin': -75.2108546, 'ymin': 7.9733472, 'xmax': -75.1828546, 'ymax': 8.0013472}}, {'address': 'Caucasia, Antioquia', 'location': {'x': -75.027360834665, 'y': 7.864559312739}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Caucasia, Antioquia', 'LongLabel': 'Caucasia, Antioquia, COL', 'ShortLabel': 'Caucasia', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Caucasia', 'Place_addr': 'Caucasia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Caucasia', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.027360834665, 'Y': 7.864559312739, 'DisplayX': -75.027360834665, 'DisplayY': 7.864559312739, 'Xmin': -75.291360834665, 'Xmax': -74.763360834665, 'Ymin': 7.600559312739, 'Ymax': 8.128559312739, 'ExInfo': ''}, 'extent': {'xmin': -75.291360834665, 'ymin': 7.600559312739, 'xmax': -74.763360834665, 'ymax': 8.128559312739}}, {'address': 'Caucasia, Antioquia', 'location': {'x': -75.19349, 'y': 7.98654}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Caucasia, Antioquia', 'LongLabel': 'Caucasia, Antioquia, COL', 'ShortLabel': 'Caucasia', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Caucasia', 'Place_addr': 'Caucasia, Antioquia', 'Phone': '', 'URL': '', 'Rank': 13.52, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Caucasia', 'MetroArea': '', 'Subregion': 'Caucasia', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.19349, 'Y': 7.98654, 'DisplayX': -75.19349, 'DisplayY': 7.98654, 'Xmin': -75.22549, 'Xmax': -75.16149, 'Ymin': 7.95454, 'Ymax': 8.01854, 'ExInfo': ''}, 'extent': {'xmin': -75.22549, 'ymin': 7.95454, 'xmax': -75.16149, 'ymax': 8.01854}}, {'address': 'Caucasia, Antioquia', 'location': {'x': -75.02858, 'y': 7.86695}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status':  ...
# Coordinates found: -75.1968546, 7.9873472
# No se pudo encontrar la vereda corregimiento palomar en el mapa de veredas.
# Asignando coordenadas del municipio caucasia.
# ---------------------------------------------------------------------
# Procesando object id 7183.
# Vereda normalizada: corregimiento mello villavicencio
# Se encontró una vereda asociada a estas coordenadas: mello villavicencio. Comparando con la vereda registrada...
# Existe similitud entre corregimiento mello villavicencio y mello villavicencio?: True
# ---------------------------------------------------------------------
# Procesando object id 11173.
# Vereda normalizada: cucurucho
# Se encontró una vereda asociada a estas coordenadas: palestina. Comparando con la vereda registrada...
# Existe similitud entre cucurucho y palestina?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para cucurucho: -75.51137224593606, 6.650980026099965
# ---------------------------------------------------------------------
# Procesando object id 4546.
# Vereda normalizada: silencio
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para silencio: -75.29206082714828, 5.839855360819827
# ---------------------------------------------------------------------
# Procesando object id 38484.
# Vereda normalizada: barlovento
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para barlovento: -75.957542891912, 5.756517925643077
# ---------------------------------------------------------------------
# Procesando object id 25233.
# Vereda normalizada: x-10
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: yondo
# ...
# Procesando object id 18580.
# Vereda normalizada: jardin
# Se encontró una vereda asociada a estas coordenadas: jardin. Comparando con la vereda registrada...
# Existe similitud entre jardin y jardin?: True
# ---------------------------------------------------------------------
# Procesando object id 38106.
# Vereda normalizada: camilo c
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para camilo c: -75.70463577510762, 6.023480638254601
# ---------------------------------------------------------------------
# Procesando object id 10780.
# Vereda normalizada: mazorcal
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: carmen viboral
# Geocode Results: [{'address': 'Carmen Viboral, El Carmen de Viboral, Antioquia', 'location': {'x': -75.33509, 'y': 6.08236}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'M', 'Score': 100, 'Match_addr': 'Carmen Viboral, El Carmen de Viboral, Antioquia', 'LongLabel': 'Carmen Viboral, El Carmen de Viboral, Antioquia, COL', 'ShortLabel': 'Carmen Viboral', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Carmen Viboral', 'Place_addr': 'Carmen de Viboral, El Carmen de Viboral, Antioquia', 'Phone': '', 'URL': '', 'Rank': 15.63, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Carmen de Viboral', 'MetroArea': '', 'Subregion': 'El Carmen de Viboral', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.33509, 'Y': 6.08236, 'DisplayX': -75.33509, 'DisplayY': 6.08236, 'Xmin': -75.36509, 'Xmax': -75.30509, 'Ymin': 6.05236, 'Ymax': 6.11236, 'ExInfo': ''}, 'extent': {'xmin': -75.36509, 'ymin': 6.05236, 'xmax': -75.30509, 'ymax': 6.11236}}, {'address': 'Carmen de Viboral, Antioquia', 'location': {'x': -75.255090496378, 'y': 5.972865508804}, 'score': 99.52, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 99.52, 'Match_addr': 'Carmen de Viboral, Antioquia', 'LongLabel': 'Carmen de Viboral, Antioquia, COL', 'ShortLabel': 'Carmen de Viboral', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Carmen de Viboral', 'Place_addr': 'Carmen de Viboral, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Carmen de Viboral', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.255090496378, 'Y': 5.972865508804, 'DisplayX': -75.255090496378, 'DisplayY': 5.972865508804, 'Xmin': -75.407090496378, 'Xmax': -75.103090496378, 'Ymin': 5.820865508804, 'Ymax': 6.124865508804, 'ExInfo': ''}, 'extent': {'xmin': -75.407090496378, 'ymin': 5.820865508804, 'xmax': -75.103090496378, 'ymax': 6.124865508804}}, {'address': 'Carmen de Viboral, Antioquia', 'location': {'x': -75.3355894, 'y': 6.0826365}, 'score': 99.52, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 99.52, 'Match_addr': 'Carmen de Viboral, Antioquia', 'LongLabel': 'Carmen de Viboral, Antioquia, COL', 'ShortLabel': 'Carmen de Viboral', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Carmen de Viboral', 'Place_addr': 'Carmen de Viboral, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Carmen de Viboral', 'City': 'Carmen de Viboral', 'MetroArea': '', 'Subregion': 'Carmen de Viboral', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.3355894, 'Y': 6.0826365, 'DisplayX': -75.3355894, 'DisplayY': 6.0826365, 'Xmin': -75.3495894, 'Xmax ...
# Coordinates found: -75.33509, 6.08236
# No se pudo encontrar la vereda mazorcal del registro 10780 en el mapa de veredas.
# Asignando coordenadas del municipio carmen viboral.
# ---------------------------------------------------------------------
# Procesando object id 16910.
# Vereda normalizada: buenos aires
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para buenos aires: -74.60285821142708, 6.559320728168098
# ---------------------------------------------------------------------
# Procesando object id 34890.
# Vereda normalizada: caceres
# No se encontró vereda con las coordenadas asignadas. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: caceres
# Geocode Results: [{'address': 'Cáceres, Antioquia', 'location': {'x': -75.227306415164, 'y': 7.674933763055}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Cáceres, Antioquia', 'LongLabel': 'Cáceres, Antioquia, COL', 'ShortLabel': 'Cáceres', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Cáceres', 'Place_addr': 'Cáceres, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Cáceres', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.227306415164, 'Y': 7.674933763055, 'DisplayX': -75.227306415164, 'DisplayY': 7.674933763055, 'Xmin': -75.502306415164, 'Xmax': -74.952306415164, 'Ymin': 7.399933763055, 'Ymax': 7.949933763055, 'ExInfo': ''}, 'extent': {'xmin': -75.502306415164, 'ymin': 7.399933763055, 'xmax': -74.952306415164, 'ymax': 7.949933763055}}, {'address': 'Cáceres, Antioquia', 'location': {'x': -75.3479796, 'y': 7.5806768}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Cáceres, Antioquia', 'LongLabel': 'Cáceres, Antioquia, COL', 'ShortLabel': 'Cáceres', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Cáceres', 'Place_addr': 'Cáceres, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Cáceres', 'City': 'Cáceres', 'MetroArea': '', 'Subregion': 'Cáceres', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.3479796, 'Y': 7.5806768, 'DisplayX': -75.3479796, 'DisplayY': 7.5806768, 'Xmin': -75.3539796, 'Xmax': -75.3419796, 'Ymin': 7.5746768, 'Ymax': 7.5866768, 'ExInfo': ''}, 'extent': {'xmin': -75.3539796, 'ymin': 7.5746768, 'xmax': -75.3419796, 'ymax': 7.5866768}}, {'address': 'Cáceres, Antioquia', 'location': {'x': -75.34842, 'y': 7.58078}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Cáceres, Antioquia', 'LongLabel': 'Cáceres, Antioquia, COL', 'ShortLabel': 'Cáceres', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Cáceres', 'Place_addr': 'Cáceres, Antioquia', 'Phone': '', 'URL': '', 'Rank': 16.79, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Cáceres', 'MetroArea': '', 'Subregion': 'Cáceres', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.34842, 'Y': 7.58078, 'DisplayX': -75.34842, 'DisplayY': 7.58078, 'Xmin': -75.35842, 'Xmax': -75.33842, 'Ymin': 7.57078, 'Ymax': 7.59078, 'ExInfo': ''}, 'extent': {'xmin': -75.35842, 'ymin': 7.57078, 'xmax': -75.33842, 'ymax': 7.59078}}, {'address': 'Cáceres, Antioquia', 'location': {'x': -75.22481, 'y': 7.68252}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Matc ...
# Coordinates found: -75.227306415164, 7.674933763055
# No se pudo encontrar la vereda caceres del registro 34890 en el mapa de veredas.
# Asignando coordenadas del municipio caceres.
# ---------------------------------------------------------------------
# Procesando object id 21594.
# Vereda normalizada: uveros
# Se encontró una vereda asociada a estas coordenadas: pueblito. Comparando con la vereda registrada...
# Existe similitud entre uveros y pueblito?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# No se encontraron coincidencias
# Geocoding municipio: san juan uraba
# Geocode Results: [{'address': 'San Juan de Urabá, Antioquia', 'location': {'x': -76.5325929938, 'y': 8.707053080828}, 'score': 99.48, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 99.48, 'Match_addr': 'San Juan de Urabá, Antioquia', 'LongLabel': 'San Juan de Urabá, Antioquia, COL', 'ShortLabel': 'San Juan de Urabá', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'San Juan de Urabá', 'Place_addr': 'San Juan de Urabá, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'San Juan de Urabá', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.5325929938, 'Y': 8.707053080828, 'DisplayX': -76.5325929938, 'DisplayY': 8.707053080828, 'Xmin': -76.6375929938, 'Xmax': -76.4275929938, 'Ymin': 8.602053080828, 'Ymax': 8.812053080828, 'ExInfo': ''}, 'extent': {'xmin': -76.6375929938, 'ymin': 8.602053080828, 'xmax': -76.4275929938, 'ymax': 8.812053080828}}, {'address': 'San Juan de Urabá, Antioquia', 'location': {'x': -76.5297291, 'y': 8.7596394}, 'score': 99.48, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 99.48, 'Match_addr': 'San Juan de Urabá, Antioquia', 'LongLabel': 'San Juan de Urabá, Antioquia, COL', 'ShortLabel': 'San Juan de Urabá', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'San Juan de Urabá', 'Place_addr': 'San Juan de Urabá, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'San Juan de Urabá', 'City': 'San Juan de Urabá', 'MetroArea': '', 'Subregion': 'San Juan de Urabá', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.5297291, 'Y': 8.7596394, 'DisplayX': -76.5297291, 'DisplayY': 8.7596394, 'Xmin': -76.5377291, 'Xmax': -76.5217291, 'Ymin': 8.7516394, 'Ymax': 8.7676394, 'ExInfo': ''}, 'extent': {'xmin': -76.5377291, 'ymin': 8.7516394, 'xmax': -76.5217291, 'ymax': 8.7676394}}, {'address': 'San Juan de Urabá, Antioquia', 'location': {'x': -76.52969, 'y': 8.75924}, 'score': 99.48, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 99.48, 'Match_addr': 'San Juan de Urabá, Antioquia', 'LongLabel': 'San Juan de Urabá, Antioquia, COL', 'ShortLabel': 'San Juan de Urabá', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'San Juan de Urabá', 'Place_addr': 'San Juan, San Juan de Urabá, Antioquia', 'Phone': '', 'URL': '', 'Rank': 18, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'San Juan', 'MetroArea': '', 'Subregion': 'San Juan de Urabá', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -76.52969, 'Y': 8.75924, 'DisplayX': -76.52969, 'DisplayY': 8.75924, 'Xmin': -76.54869, 'Xmax': -76.51069, 'Ymin': 8.74024, 'Ymax': 8.77824, 'ExInfo': ''}, 'extent': { ...
# Coordinates found: -76.5325929938, 8.707053080828
# No se pudo encontrar la vereda uveros en el mapa de veredas.
# Asignando coordenadas del municipio san juan uraba.
# ---------------------------------------------------------------------
# Procesando object id 34824.
# Vereda normalizada: currulao
# Se encontró una vereda asociada a estas coordenadas: tio gil. Comparando con la vereda registrada...
# Existe similitud entre currulao y tio gil?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para currulao: -76.62111627213731, 8.001899153131282
# ---------------------------------------------------------------------
# Procesando object id 20947.
# Vereda normalizada: siberia
# Se encontró una vereda asociada a estas coordenadas: taborda. Comparando con la vereda registrada...
# Existe similitud entre siberia y taborda?: False
# Similitud entre ambas veredas idemasiado baja o inexistente. Buscando coordenadas de la vereda registrada...
# Coordenadas encontradas para siberia: -75.37359809218914, 7.338387651577445
# 1      None
# 4      None
# 8      None
# 9      None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 20     None
# 29     None
# 30     None
# 35     None
# 37     None
# 38     None
# 50     None
# 52     None
# 53     None
# 54     None
# 56     None
# 58     None
# 62     None
# 63     None
# 65     None
# 67     None
# 72     None
# 73     None
# 76     None
# 78     None
# 80     None
# 81     None
# 82     None
# 85     None
# 86     None
# 89     None
# 92     None
# 93     None
# 94     None
# 96     None
# 100    None
# 104    None
# 106    None
# 110    None
# 111    None
# 112    None
# 114    None
# 117    None
# 118    None
# 130    None
# 133    None
# 142    None
# 146    None
# 149    None
# dtype: object

# %% [markdown]
# ## Procesamiento de coordenadas en la zona urbana
#
# ### Verificación de coordenadas
#
# ![image.png](attachment:image.png)
#
# Debido a las limitaciones en el alcance del presente entregable, se tomó la decisión de verificar únicamente, en el caso de las coordenadas pertenecientes a un registro en una Zona Urbana, si las coordenadas presentes registradas estaban dentro del municipio correspondiente. En caso contrario, se le asignan las coordenadas por defecto del municipio.

# %%
def asignar_municipio(municipio):
    print(municipio)
    new_x, new_y = ag.geocode_municipio(municipio)
    print(f"Nuevas coordenadas: {new_x}, {new_y}")
    return new_x, new_y


def procesar_coordenadas_municipio(row):

    municipio_dataset = row["Municipio_normalizado"]
    id = row["ObjectID"]
    print("---------------------------------------------------------------------")
    print(f"Procesando object id {id}. \nMunicipio normalizado: {municipio_dataset}")
    # Saber si las coordenadas registradas hacen parte de algún municipio y cuál
    x = row["x"]
    y = row["y"]
    municipio = ag.reverse_geocode_municipio(x, y)
    if municipio == None:
        print(f"No se encontró el municipio en las coordenadas x, y: {x}, {y}")
        municipio = row["Municipio_normalizado"]
        row["x"], row["y"] = asignar_municipio(municipio)
    else:
        # Normalizar nombre del municipio
        municipio = str(municipio)
        municipio_arcgis = norm.normalizar_texto(municipio)

        # Comparar nombre normalizado del municipio (Se consideran válidas si coinciden al menos en un 70%)
        similitud = cd.comparar_frases(municipio_arcgis, municipio_dataset, 70)
        

        # Si la similitud entre el municipio que marcan las coordenadas y el del dataset es menor al 70%, se ponen las coordenadas del municipio original
        if not similitud:
            print(f"Similitud entre {municipio_dataset} y {municipio_arcgis}: {similitud}")
            municipio = row["Municipio de residencia (PcD)"]
            row["x"], row["y"] = asignar_municipio(municipio)


df_urbano.apply(procesar_coordenadas_municipio, axis=1)
# Out:
# ---------------------------------------------------------------------
# Procesando object id 29757.
# Municipio normalizado: itagui
# Reverse geocoding coordinates: -75.61424, 6.16548
# Reverse Geocode Result: {'address': {'Match_addr': 'Distribuidora Accesorios S A S', 'LongLabel': 'Distribuidora Accesorios S A S, Diagonal 38a 34 14, San Jose, Itagüí, Antioquia, COL', 'ShortLabel': 'Distribuidora Accesorios S A S', 'Addr_type': 'POI', 'Type': 'Clothing Store', 'PlaceName': 'Distribuidora Accesorios S A S', 'AddNum': '34 14', 'Address': 'Diagonal 38a 34 14', 'Block': '', 'Sector': '', 'Neighborhood': 'San Jose', 'District': 'Itagüí', 'City': 'Itagüí', 'MetroArea': '', 'Subregion': 'Itagüí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '055412', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.614186490132, 'Y': 6.163959344018, 'InputX': -75.61424, 'InputY': 6.16548}, 'location': {'x': -75.614186490132, 'y': 6.163959344018, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Itagüí
# ---------------------------------------------------------------------
# Procesando object id 13723.
# Municipio normalizado: anori
# Reverse geocoding coordinates: -75.14706421, 7.073713302
# Reverse Geocode Result: {'address': {'Match_addr': 'Gaviria Correa Diego', 'LongLabel': 'Gaviria Correa Diego, Calle 30 31 38, Anorí, Antioquia, COL', 'ShortLabel': 'Gaviria Correa Diego', 'Addr_type': 'POI', 'Type': 'Consumer Electronics Store', 'PlaceName': 'Gaviria Correa Diego', 'AddNum': '31 38', 'Address': 'Calle 30 31 38', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': 'Anorí', 'City': 'Anorí', 'MetroArea': '', 'Subregion': 'Anorí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '052850', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.14709994418, 'Y': 7.073643739252, 'InputX': -75.14706421, 'InputY': 7.073713302}, 'location': {'x': -75.14709994418, 'y': 7.073643739252, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Anorí
# ---------------------------------------------------------------------
# Procesando object id 17800.
# Municipio normalizado: cisneros
# Reverse geocoding coordinates: -75.0859026, 6.5390412
# Reverse Geocode Result: {'address': {'Match_addr': 'Muneton Patino Fernando Alberto', 'LongLabel': 'Muneton Patino Fernando Alberto, Calle 20 21 27, Cisneros, Antioquia, COL', 'ShortLabel': 'Muneton Patino Fernando Alberto', 'Addr_type': 'POI', 'Type': 'Bookstore', 'PlaceName': 'Muneton Patino Fernando Alberto', 'AddNum': '21 27', 'Address': 'Calle 20 21 27', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': 'Cisneros', 'City': 'Cisneros', 'MetroArea': '', 'Subregion': 'Cisneros', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '053050', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.0860249, 'Y': 6.539066778926, 'InputX': -75.0859026, 'InputY': 6.5390412}, 'location': {'x': -75.0860249, 'y': 6.539066778926, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Cisneros
# ---------------------------------------------------------------------
# Procesando object id 33242.
# Municipio normalizado: bello
# Reverse geocoding coordinates: -75.54471, 6.24488
# Reverse Geocode Result: {'address': {'Match_addr': 'Carrera 25A 56B-2-56B-100, El Pinal, Medellín, Antioquia', 'LongLabel': 'Carrera 25A 56B-2-56B-100, El Pinal, Medellín, Antioquia, COL', 'ShortLabel': 'Carrera 25A 56B-2-56B-100', 'Addr_type': 'StreetAddress', 'Type': '', 'PlaceName': '', 'AddNum': '56B-54', 'Address': 'Carrera 25A 56B-54', 'Block': '', 'Sector': '', 'Neighborhood': 'El Pinal', 'District': 'El Pinal', 'City': 'Medellín', 'MetroArea': '', 'Subregion': 'Medellín', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '050013', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.544674293961, 'Y': 6.244838729796, 'InputX': -75.54471, 'InputY': 6.24488}, 'location': {'x': -75.544674293961, 'y': 6.244838729796, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Medellín
# Similitud entre bello y medellin: False
# Bello
# Geocoding municipio: Bello
# Geocode Results: [{'address': 'Bello, Antioquia', 'location': {'x': -75.55828, 'y': 6.33493}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Bello, Antioquia', 'LongLabel': 'Bello, Antioquia, COL', 'ShortLabel': 'Bello', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Bello', 'Place_addr': 'Bello, Antioquia', 'Phone': '', 'URL': '', 'Rank': 8.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Bello', 'City': 'Bello', 'MetroArea': '', 'Subregion': 'Bello', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.55828, 'Y': 6.33493, 'DisplayX': -75.55828, 'DisplayY': 6.33493, 'Xmin': -75.59328, 'Xmax': -75.52328, 'Ymin': 6.29993, 'Ymax': 6.36993, 'ExInfo': ''}, 'extent': {'xmin': -75.59328, 'ymin': 6.29993, 'xmax': -75.52328, 'ymax': 6.36993}}, {'address': 'Bello, Antioquia', 'location': {'x': -75.58978181708, 'y': 6.35885711789}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Bello, Antioquia', 'LongLabel': 'Bello, Antioquia, COL', 'ShortLabel': 'Bello', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Bello', 'Place_addr': 'Bello, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Bello', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.58978181708, 'Y': 6.35885711789, 'DisplayX': -75.58978181708, 'DisplayY': 6.35885711789, 'Xmin': -75.66478181708, 'Xmax': -75.51478181708, 'Ymin': 6.28385711789, 'Ymax': 6.43385711789, 'ExInfo': ''}, 'extent': {'xmin': -75.66478181708, 'ymin': 6.28385711789, 'xmax': -75.51478181708, 'ymax': 6.43385711789}}, {'address': 'Bello, Antioquia', 'location': {'x': -75.55795, 'y': 6.33732}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Bello, Antioquia', 'LongLabel': 'Bello, Antioquia, COL', 'ShortLabel': 'Bello', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Bello', 'Place_addr': 'Bello, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Bello', 'MetroArea': '', 'Subregion': 'Bello', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.55795, 'Y': 6.33732, 'DisplayX': -75.55795, 'DisplayY': 6.33732, 'Xmin': -75.64095, 'Xmax': -75.47495, 'Ymin': 6.25432, 'Ymax': 6.42032, 'ExInfo': ''}, 'extent': {'xmin': -75.64095, 'ymin': 6.25432, 'xmax': -75.47495, 'ymax': 6.42032}}, {'address': 'Bello, Antioquia', 'location': {'x': -75.58728, 'y': 6.3616}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Bello, Antioquia', 'LongLabel': 'Bello, Antioquia, COL', 'ShortLabel': 'Bello', 'Addr ...
# Coordinates found: -75.55828, 6.33493
# Nuevas coordenadas: -75.55828, 6.33493
# ---------------------------------------------------------------------
# Procesando object id 16509.
# Municipio normalizado: rionegro
# Reverse geocoding coordinates: -75.3892318, 6.1492612
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 42 69a 39, Rionegro, Antioquia', 'LongLabel': 'Calle 42 69a 39, Rionegro, Antioquia, COL', 'ShortLabel': 'Calle 42 69a 39', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '39', 'Address': 'Calle 42 69a 39', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '054040', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.389174621268, 'Y': 6.149572528037, 'InputX': -75.3892318, 'InputY': 6.1492612}, 'location': {'x': -75.389174621268, 'y': 6.149572528037, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Rionegro
# ---------------------------------------------------------------------
# Procesando object id 11629.
# Municipio normalizado: sabaneta
# Reverse geocoding coordinates: -75.61885834, 6.148209095
# Reverse Geocode Result: {'address': {'Match_addr': 'Carrera 45 75Bs-2-75Bs-62, San José, Sabaneta, Antioquia', 'LongLabel': 'Carrera 45 75Bs-2-75Bs-62, San José, Sabaneta, Antioquia, COL', 'ShortLabel': 'Carrera 45 75Bs-2-75Bs-62', 'Addr_type': 'StreetAddress', 'Type': '', 'PlaceName': '', 'AddNum': '75Bs-28', 'Address': 'Carrera 45 75Bs-28', 'Block': '', 'Sector': '', 'Neighborhood': 'San José', 'District': 'Sabaneta', 'City': 'Sabaneta', 'MetroArea': '', 'Subregion': 'Sabaneta', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '055450', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.618893071361, 'Y': 6.148210464989, 'InputX': -75.61885834, 'InputY': 6.148209095}, 'location': {'x': -75.618893071361, 'y': 6.148210464989, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Sabaneta
# ---------------------------------------------------------------------
# Procesando object id 21147.
# Municipio normalizado: carmen viboral
# Reverse geocoding coordinates: -75.35333574, 6.11062448
# Reverse Geocode Result: {'address': {'Match_addr': 'Cristo Rey, Carmen de Viboral, Antioquia', 'LongLabel': 'Cristo Rey, Carmen de Viboral, Antioquia, COL', 'ShortLabel': 'Cristo Rey', 'Addr_type': 'Locality', 'Type': 'Neighborhood', 'PlaceName': 'Cristo Rey', 'AddNum': '', 'Address': '', 'Block': '', 'Sector': '', 'Neighborhood': 'Cristo Rey', 'District': '', 'City': 'Carmen de Viboral', 'MetroArea': '', 'Subregion': 'Carmen de Viboral', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.35333574, 'Y': 6.11062448, 'InputX': -75.35333574, 'InputY': 6.11062448}, 'location': {'x': -75.35333574, 'y': 6.11062448, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Carmen de Viboral
# ---------------------------------------------------------------------
# Procesando object id 46866.
# Municipio normalizado: barbosa
# Reverse geocoding coordinates: -75.3330237, 6.4385949
# Reverse Geocode Result: {'address': {'Match_addr': 'Tecnomovil Barbosa', 'LongLabel': 'Tecnomovil Barbosa, Calle 10 8-18, Urbanal, Barbosa, Antioquia, COL', 'ShortLabel': 'Tecnomovil Barbosa', 'Addr_type': 'POI', 'Type': 'Mobile Phone Shop', 'PlaceName': 'Tecnomovil Barbosa', 'AddNum': '8-18', 'Address': 'Calle 10 8-18', 'Block': '', 'Sector': '', 'Neighborhood': 'Urbanal', 'District': 'Barbosa', 'City': 'Barbosa', 'MetroArea': '', 'Subregion': 'Barbosa', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '051020', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.334121633534, 'Y': 6.437292900484, 'InputX': -75.3330237, 'InputY': 6.4385949}, 'location': {'x': -75.334121633534, 'y': 6.437292900484, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Barbosa
# ---------------------------------------------------------------------
# Procesando object id 10598.
# Municipio normalizado: caldas
# Reverse geocoding coordinates: -75.63827515, 6.081191062
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 139c S 52 200, Caldas, Antioquia', 'LongLabel': 'Calle 139c S 52 200, Caldas, Antioquia, COL', 'ShortLabel': 'Calle 139c S 52 200', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '200', 'Address': 'Calle 139c S 52 200', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Caldas', 'MetroArea': '', 'Subregion': 'Caldas', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '055448', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.638344965707, 'Y': 6.081180011891, 'InputX': -75.63827515, 'InputY': 6.081191062}, 'location': {'x': -75.638344965707, 'y': 6.081180011891, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Caldas
# ---------------------------------------------------------------------
# Procesando object id 16873.
# Municipio normalizado: caucasia
# Reverse geocoding coordinates: -75.19348, 7.9758283
# Reverse Geocode Result: {'address': {'Match_addr': 'Carrera 3, Caucasia, Antioquia', 'LongLabel': 'Carrera 3, Caucasia, Antioquia, COL', 'ShortLabel': 'Carrera 3', 'Addr_type': 'StreetName', 'Type': '', 'PlaceName': '', 'AddNum': '', 'Address': 'Carrera 3', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': 'Caucasia', 'City': 'Caucasia', 'MetroArea': '', 'Subregion': 'Caucasia', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '052410', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.193465131669, 'Y': 7.975829585382, 'InputX': -75.19348, 'InputY': 7.9758283}, 'location': {'x': -75.193465131669, 'y': 7.975829585382, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Caucasia
# ---------------------------------------------------------------------
# Procesando object id 10180.
# Municipio normalizado: yondo
# Reverse geocoding coordinates: -73.91081238, 7.004271984
# Reverse Geocode Result: {'address': {'Match_addr': 'Manco Sanchez Alexis Marcela', 'LongLabel': 'Manco Sanchez Alexis Marcela, Carrera 55 46 33, La Represa, Yondó, Antioquia, COL', 'ShortLabel': 'Manco Sanchez Alexis Marcela', 'Addr_type': 'POI', 'Type': 'Spanish Food', 'PlaceName': 'Manco Sanchez Alexis Marcela', 'AddNum': '46 33', 'Address': 'Carrera 55 46 33', 'Block': '', 'Sector': '', 'Neighborhood': 'La Represa', 'District': 'Yondó', 'City': 'Yondó', 'MetroArea': '', 'Subregion': 'Yondó', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '053410', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -73.910610181274, 'Y': 7.004172456368, 'InputX': -73.91081238, 'InputY': 7.004271984}, 'location': {'x': -73.910610181274, 'y': 7.004172456368, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Yondó
# ---------------------------------------------------------------------
# Procesando object id 11884.
# Municipio normalizado: sabaneta
# Reverse geocoding coordinates: -75.61872101, 6.148137092
# Reverse Geocode Result: {'address': {'Match_addr': 'Carrera 45 75b S 42, Sabaneta, Antioquia', 'LongLabel': 'Carrera 45 75b S 42, Sabaneta, Antioquia, COL', 'ShortLabel': 'Carrera 45 75b S 42', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '42', 'Address': 'Carrera 45 75b S 42', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Sabaneta', 'MetroArea': '', 'Subregion': 'Sabaneta', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '055450', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.618802726091, 'Y': 6.148323750192, 'InputX': -75.61872101, 'InputY': 6.148137092}, 'location': {'x': -75.618802726091, 'y': 6.148323750192, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Sabaneta
# ---------------------------------------------------------------------
# Procesando object id 36176.
# Municipio normalizado: rionegro
# Reverse geocoding coordinates: -75.37413, 6.15367
# Reverse Geocode Result: {'address': {'Match_addr': 'Broadway Rionegro', 'LongLabel': 'Broadway Rionegro, Carrera 51 48 90, Chipre, Rionegro, Antioquia, COL', 'ShortLabel': 'Broadway Rionegro', 'Addr_type': 'POI', 'Type': 'Specialty Store', 'PlaceName': 'Broadway Rionegro', 'AddNum': '48 90', 'Address': 'Carrera 51 48 90', 'Block': '', 'Sector': '', 'Neighborhood': 'Chipre', 'District': 'Rionegro', 'City': 'Rionegro', 'MetroArea': '', 'Subregion': 'Rionegro', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '054040', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.374493187865, 'Y': 6.153888264759, 'InputX': -75.37413, 'InputY': 6.15367}, 'location': {'x': -75.374493187865, 'y': 6.153888264759, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Rionegro
# ---------------------------------------------------------------------
# Procesando object id 30102.
# Municipio normalizado: itagui
# Reverse geocoding coordinates: -75.59858, 6.17981
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 66 47-100-47-2, Simon Bolívar, Itagüí, Antioquia', 'LongLabel': 'Calle 66 47-100-47-2, Simon Bolívar, Itagüí, Antioquia, COL', 'ShortLabel': 'Calle 66 47-100-47-2', 'Addr_type': 'StreetAddress', 'Type': '', 'PlaceName': '', 'AddNum': '47-42', 'Address': 'Calle 66 47-42', 'Block': '', 'Sector': '', 'Neighborhood': 'Simon Bolívar', 'District': 'Itagüí', 'City': 'Itagüí', 'MetroArea': '', 'Subregion': 'Itagüí', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '055411', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.598553757822, 'Y': 6.179840797202, 'InputX': -75.59858, 'InputY': 6.17981}, 'location': {'x': -75.598553757822, 'y': 6.179840797202, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Itagüí
# ---------------------------------------------------------------------
# Procesando object id 22141.
# Municipio normalizado: yarumal
# Reverse geocoding coordinates: -75.41640248, 6.953991498
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 11 26d 13, Yarumal, Antioquia', 'LongLabel': 'Calle 11 26d 13, Yarumal, Antioquia, COL', 'ShortLabel': 'Calle 11 26d 13', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '13', 'Address': 'Calle 11 26d 13', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Yarumal', 'MetroArea': '', 'Subregion': 'Yarumal', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '052037', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.416226794671, 'Y': 6.953853521009, 'InputX': -75.41640248, 'InputY': 6.953991498}, 'location': {'x': -75.416226794671, 'y': 6.953853521009, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Yarumal
# ---------------------------------------------------------------------
# Procesando object id 12606.
# Municipio normalizado: guarne
# Reverse geocoding coordinates: 5.68434e-14, 5.68434e-14
# Reverse Geocode Result: {'address': {'Match_addr': 'Earth', 'LongLabel': 'Earth', 'ShortLabel': 'Earth', 'Addr_type': 'POI', 'Type': 'Other Land Feature', 'PlaceName': 'Earth', 'AddNum': '', 'Address': '', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': '', 'Region': '', 'RegionAbbr': '', 'Territory': '', 'Postal': '', 'PostalExt': '', 'CntryName': '', 'CountryCode': '', 'X': 0.0, 'Y': 0.0, 'InputX': 0.0, 'InputY': 0.0}, 'location': {'x': 0.0, 'y': 0.0, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Municipio not found in the reverse geocode result.
# Similitud entre guarne y not found: False
# Guarne
# Geocoding municipio: Guarne
# Geocode Results: [{'address': 'Guarne, Antioquia', 'location': {'x': -75.433977659853, 'y': 6.268247581614}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Guarne, Antioquia', 'LongLabel': 'Guarne, Antioquia, COL', 'ShortLabel': 'Guarne', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'Guarne', 'Place_addr': 'Guarne, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'Guarne', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.433977659853, 'Y': 6.268247581614, 'DisplayX': -75.433977659853, 'DisplayY': 6.268247581614, 'Xmin': -75.507977659853, 'Xmax': -75.359977659853, 'Ymin': 6.194247581614, 'Ymax': 6.342247581614, 'ExInfo': ''}, 'extent': {'xmin': -75.507977659853, 'ymin': 6.194247581614, 'xmax': -75.359977659853, 'ymax': 6.342247581614}}, {'address': 'Guarne, Antioquia', 'location': {'x': -75.44235, 'y': 6.27942}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Guarne, Antioquia', 'LongLabel': 'Guarne, Antioquia, COL', 'ShortLabel': 'Guarne', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Guarne', 'Place_addr': 'Guarne, Antioquia', 'Phone': '', 'URL': '', 'Rank': 10.5, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': 'Guarne', 'City': 'Guarne', 'MetroArea': '', 'Subregion': 'Guarne', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.44235, 'Y': 6.27942, 'DisplayX': -75.44235, 'DisplayY': 6.27942, 'Xmin': -75.46635, 'Xmax': -75.41835, 'Ymin': 6.25542, 'Ymax': 6.30342, 'ExInfo': ''}, 'extent': {'xmin': -75.46635, 'ymin': 6.25542, 'xmax': -75.41835, 'ymax': 6.30342}}, {'address': 'Guarne, Antioquia', 'location': {'x': -75.44354, 'y': 6.28046}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Guarne, Antioquia', 'LongLabel': 'Guarne, Antioquia, COL', 'ShortLabel': 'Guarne', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'Guarne', 'Place_addr': 'Guarne, Antioquia', 'Phone': '', 'URL': '', 'Rank': 16.3, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'Guarne', 'MetroArea': '', 'Subregion': 'Guarne', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.44354, 'Y': 6.28046, 'DisplayX': -75.44354, 'DisplayY': 6.28046, 'Xmin': -75.45954, 'Xmax': -75.42754, 'Ymin': 6.26446, 'Ymax': 6.29646, 'ExInfo': ''}, 'extent': {'xmin': -75.45954, 'ymin': 6.26446, 'xmax': -75.42754, 'ymax': 6.29646}}, {'address': 'Guarne, Antioquia', 'location': {'x': -75.44363, 'y': 6.28345}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'Guarne, Antioquia', 'LongLabel': 'Guarne, An ...
# Coordinates found: -75.433977659853, 6.268247581614
# Nuevas coordenadas: -75.433977659853, 6.268247581614
# ---------------------------------------------------------------------
# Procesando object id 38563.
# Municipio normalizado: amalfi
# Reverse geocoding coordinates: -75.0755331, 6.9078282
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 20 21 19, Amalfi, Antioquia', 'LongLabel': 'Calle 20 21 19, Amalfi, Antioquia, COL', 'ShortLabel': 'Calle 20 21 19', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '19', 'Address': 'Calle 20 21 19', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Amalfi', 'MetroArea': '', 'Subregion': 'Amalfi', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '052840', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.075546603219, 'Y': 6.907880374653, 'InputX': -75.0755331, 'InputY': 6.9078282}, 'location': {'x': -75.075546603219, 'y': 6.907880374653, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Amalfi
# ---------------------------------------------------------------------
# Procesando object id 26811.
# Municipio normalizado: carmen viboral
# Reverse geocoding coordinates: -75.33311333, 6.094656667
# Reverse Geocode Result: {'address': {'Match_addr': 'Carrera 25C 43C-18-43C-18, Camargo, Carmen de Viboral, Antioquia', 'LongLabel': 'Carrera 25C 43C-18-43C-18, Camargo, Carmen de Viboral, Antioquia, COL', 'ShortLabel': 'Carrera 25C 43C-18-43C-18', 'Addr_type': 'StreetAddress', 'Type': '', 'PlaceName': '', 'AddNum': '43C-180', 'Address': 'Carrera 25C 43C-180', 'Block': '', 'Sector': '', 'Neighborhood': 'Camargo', 'District': 'Carmen de Viboral', 'City': 'Carmen de Viboral', 'MetroArea': '', 'Subregion': 'Carmen de Viboral', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '054030', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.33308663162, 'Y': 6.094693463902, 'InputX': -75.33311333, 'InputY': 6.094656667}, 'location': {'x': -75.33308663162, 'y': 6.094693463902, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Carmen de Viboral
# ---------------------------------------------------------------------
# Procesando object id 26004.
# Municipio normalizado: barbosa
# Reverse geocoding coordinates: -75.32917219, 6.435026935
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 15 8 179, Barbosa, Antioquia', 'LongLabel': 'Calle 15 8 179, Barbosa, Antioquia, COL', 'ShortLabel': 'Calle 15 8 179', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '179', 'Address': 'Calle 15 8 179', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Barbosa', 'MetroArea': '', 'Subregion': 'Barbosa', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '051020', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.329055672199, 'Y': 6.435128504613, 'InputX': -75.32917219, 'InputY': 6.435026935}, 'location': {'x': -75.329055672199, 'y': 6.435128504613, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Barbosa
# ---------------------------------------------------------------------
# Procesando object id 10035.
# Municipio normalizado: pintada
# Reverse geocoding coordinates: -75.56459808, 6.252900124
# Reverse Geocode Result: {'address': {'Match_addr': 'Parque Bolívar', 'LongLabel': 'Parque Bolívar, Carrera 48, Villa Nueva, Medellín, Antioquia, COL', 'ShortLabel': 'Parque Bolívar', 'Addr_type': 'POI', 'Type': 'Park', 'PlaceName': 'Parque Bolívar', 'AddNum': '', 'Address': 'Carrera 48', 'Block': '', 'Sector': '', 'Neighborhood': 'Villa Nueva', 'District': 'Villa Nueva', 'City': 'Medellín', 'MetroArea': '', 'Subregion': 'Medellín', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '050012', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.564290504732, 'Y': 6.252838053742, 'InputX': -75.56459808, 'InputY': 6.252900124}, 'location': {'x': -75.564290504732, 'y': 6.252838053742, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Medellín
# Similitud entre pintada y medellin: False
# La Pintada
# Geocoding municipio: La Pintada
# Geocode Results: [{'address': 'La Pintada, Antioquia', 'location': {'x': -75.6063176, 'y': 5.746669}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'La Pintada, Antioquia', 'LongLabel': 'La Pintada, Antioquia, COL', 'ShortLabel': 'La Pintada', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'La Pintada', 'Place_addr': 'La Pintada, Antioquia', 'Phone': '', 'URL': '', 'Rank': 11.7, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'La Pintada', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.6063176, 'Y': 5.746669, 'DisplayX': -75.6063176, 'DisplayY': 5.746669, 'Xmin': -75.6593176, 'Xmax': -75.5533176, 'Ymin': 5.693669, 'Ymax': 5.799669, 'ExInfo': ''}, 'extent': {'xmin': -75.6593176, 'ymin': 5.693669, 'xmax': -75.5533176, 'ymax': 5.799669}}, {'address': 'La Pintada, Antioquia', 'location': {'x': -75.60626, 'y': 5.74867}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'La Pintada, Antioquia', 'LongLabel': 'La Pintada, Antioquia, COL', 'ShortLabel': 'La Pintada', 'Addr_type': 'Locality', 'Type': 'City', 'PlaceName': 'La Pintada', 'Place_addr': 'La Pintada, Antioquia', 'Phone': '', 'URL': '', 'Rank': 16.77, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': 'La Pintada', 'MetroArea': '', 'Subregion': 'La Pintada', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.60626, 'Y': 5.74867, 'DisplayX': -75.60626, 'DisplayY': 5.74867, 'Xmin': -75.61626, 'Xmax': -75.59626, 'Ymin': 5.73867, 'Ymax': 5.75867, 'ExInfo': ''}, 'extent': {'xmin': -75.61626, 'ymin': 5.73867, 'xmax': -75.59626, 'ymax': 5.75867}}, {'address': 'La Pintada, Antioquia', 'location': {'x': -75.60023, 'y': 5.7508}, 'score': 100, 'attributes': {'Loc_name': 'World', 'Status': 'T', 'Score': 100, 'Match_addr': 'La Pintada, Antioquia', 'LongLabel': 'La Pintada, Antioquia, COL', 'ShortLabel': 'La Pintada', 'Addr_type': 'Locality', 'Type': 'County', 'PlaceName': 'La Pintada', 'Place_addr': 'La Pintada, Antioquia', 'Phone': '', 'URL': '', 'Rank': 19, 'AddBldg': '', 'AddNum': '', 'AddNumFrom': '', 'AddNumTo': '', 'AddRange': '', 'Side': '', 'StPreDir': '', 'StPreType': '', 'StName': '', 'StType': '', 'StDir': '', 'BldgType': '', 'BldgName': '', 'LevelType': '', 'LevelName': '', 'UnitType': '', 'UnitName': '', 'SubAddr': '', 'StAddr': '', 'Block': '', 'Sector': '', 'Nbrhd': '', 'District': '', 'City': '', 'MetroArea': '', 'Subregion': 'La Pintada', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Zone': '', 'Postal': '', 'PostalExt': '', 'Country': 'COL', 'CntryName': 'Colombia', 'LangCode': 'SPA', 'Distance': 0, 'X': -75.60023, 'Y': 5.7508, 'DisplayX': -75.60023, 'DisplayY': 5.7508, 'Xmin': -75.66223, 'Xmax': -75.53823, 'Ymin': 5.6888, 'Ymax': 5.8128, 'ExInfo': ''}, 'extent': {'xmin': -75.66223, 'ymin': 5.6888, 'xmax': -75.53823, 'ymax': 5.8128}}]
# Coordinates found: -75.6063176, 5.746669
# Nuevas coordenadas: -75.6063176, 5.746669
# ---------------------------------------------------------------------
# Procesando object id 25047.
# Municipio normalizado: segovia
# Reverse geocoding coordinates: -74.70321277, 7.073737776
# Reverse Geocode Result: {'address': {'Match_addr': 'Carrera 52 44 76, Segovia, Antioquia', 'LongLabel': 'Carrera 52 44 76, Segovia, Antioquia, COL', 'ShortLabel': 'Carrera 52 44 76', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '76', 'Address': 'Carrera 52 44 76', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Segovia', 'MetroArea': '', 'Subregion': 'Segovia', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '052810', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -74.703488254316, 'Y': 7.073694494122, 'InputX': -74.70321277, 'InputY': 7.073737776}, 'location': {'x': -74.703488254316, 'y': 7.073694494122, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Segovia
# ---------------------------------------------------------------------
# Procesando object id 33659.
# Municipio normalizado: san francisco
# Reverse geocoding coordinates: -75.10680025, 5.968967708
# Reverse Geocode Result: {'address': {'Match_addr': '054817, San Francisco, Antioquia', 'LongLabel': '054817, San Francisco, Antioquia, COL', 'ShortLabel': '054817', 'Addr_type': 'Postal', 'Type': '', 'PlaceName': '054817', 'AddNum': '', 'Address': '', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'San Francisco', 'MetroArea': '', 'Subregion': 'San Francisco', 'Region': 'Antioquia', 'RegionAbbr': 'ANT', 'Territory': '', 'Postal': '054817', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.10680025, 'Y': 5.968967708, 'InputX': -75.10680025, 'InputY': 5.968967708}, 'location': {'x': -75.10680025, 'y': 5.968967708, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: San Francisco
# ---------------------------------------------------------------------
# Procesando object id 26628.
# Municipio normalizado: san luis
# Reverse geocoding coordinates: -74.99168667, 6.042098333
# Reverse Geocode Result: {'address': {'Match_addr': 'Carrera 18 17 40, San Luis, Antioquia', 'LongLabel': 'Carrera 18 17 40, San Luis, Antioquia, COL', 'ShortLabel': 'Carrera 18 17 40', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '40', 'Address': 'Carrera 18 17 40', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'San Luis', 'MetroArea': '', 'Subregion': 'San Luis', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '054430', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -74.991973412685, 'Y': 6.042102112454, 'InputX': -74.99168667, 'InputY': 6.042098333}, 'location': {'x': -74.991973412685, 'y': 6.042102112454, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: San Luis
# ---------------------------------------------------------------------
# Procesando object id 26421.
# Municipio normalizado: granada
# Reverse geocoding coordinates: -75.1844786, 6.143974256
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 21 21 65, Granada, Antioquia', 'LongLabel': 'Calle 21 21 65, Granada, Antioquia, COL', 'ShortLabel': 'Calle 21 21 65', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '65', 'Address': 'Calle 21 21 65', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Granada', 'MetroArea': '', 'Subregion': 'Granada', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '054410', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.184392908208, 'Y': 6.143987833589, 'InputX': -75.1844786, 'InputY': 6.143974256}, 'location': {'x': -75.184392908208, 'y': 6.143987833589, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Granada
# ---------------------------------------------------------------------
# Procesando object id 37732.
# Municipio normalizado: bello
# Reverse geocoding coordinates: -75.56071541, 6.348644244
# Reverse Geocode Result: {'address': {'Match_addr': 'Calle 69 57 05, Bello, Antioquia', 'LongLabel': 'Calle 69 57 05, Bello, Antioquia, COL', 'ShortLabel': 'Calle 69 57 05', 'Addr_type': 'PointAddress', 'Type': '', 'PlaceName': '', 'AddNum': '05', 'Address': 'Calle 69 57 05', 'Block': '', 'Sector': '', 'Neighborhood': '', 'District': '', 'City': 'Bello', 'MetroArea': '', 'Subregion': 'Bello', 'Region': 'Antioquia', 'RegionAbbr': '', 'Territory': '', 'Postal': '051054', 'PostalExt': '', 'CntryName': 'Colombia', 'CountryCode': 'COL', 'X': -75.560673808474, 'Y': 6.348677345714, 'InputX': -75.56071541, 'InputY': 6.348644244}, 'location': {'x': -75.560673808474, 'y': 6.348677345714, 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}
# Found municipio: Bello
# ---------------------------------------------------------------------
# Procesando object id 20661.
# Municipio normalizado: zaragoza
# Reverse geocoding coordinates: -74.857880259715, 7.475101404504

# %% [markdown]
# ## Unificación de datasets
#
# En pasos anteriores se dividió el dataset en dos, uno para zona rural y otro para la zona urbana. A continuación se unificarán para la posterior generación del dataset limpio.

# %%
import pandas as pd

df_combined = pd.concat([df_rural, df_urbano], ignore_index=True)
print(df_combined.head())
# Out:
#   ObjectID Fecha de la encuesta Nombres y apellidos del encuestador  \
# 0    36555           24/07/2023                      Leandro Garcia
# 1     4565      6/07/2024 17:00                         Erica henao
# 2    31956     19/01/2022 17:00      Maria Yuliana Presiga Cardona
# 3    43501  2024-08-12 18:00:00           Anthony Alzate sepulveda
# 4    30359     16/11/2022 17:00      Maria Del Carmen Baldrich Mena
#
#   Tipo de documento del encuestador Numero de documento del encuestador  \
# 0              Cedula de ciudadania                          15445072.0
# 1              Cedula de ciudadania                        1040261406.0
# 2              Cedula de ciudadania                        1028121041.0
# 3              Cedula de ciudadania                        1033176597.0
# 4              Cedula de ciudadania                        1016016541.0
#
#    Subregion (PcD) Municipio de residencia (PcD) Zona de residencia (PcD)  \
# 0          Oriente                      Rionegro                    Rural
# 1          Oriente                 San Francisco                    Rural
# 2        Occidente                       Armenia                    Rural
# 3  Magdalena Medio                   Puerto Nare                    Rural
# 4            Uraba                      Apartado                    Rural
#
#        Nombre del Barrio o Vereda (PcD) Direccion de la residencia (PcD)  ...  \
# 0                             El Capiro                 VEREDA EL CAPIRO  ...
# 1                            La inojosa                       La inojosa  ...
# 2                            PALMICHAL                   Calle 10 # 9-22  ...
# 3  20 de enero corregimiento la sierra                  cra 4 nro 16-119  ...
# 4                   Vereda Bajo del Oso           kilomtre 2 via a Turbo  ...
#
#   A que espacios de participacion pertenece Consentimiento Informado  \
# 0                                       NaN                 autorizo
# 1                                   Ninguno                 autorizo
# 2                                       NaN                 autorizo
# 3                                   Ninguno                 autorizo
# 4                                       NaN                 autorizo
#
#               CreationDate                 EditDate  \
# 0  08/01/2024 21:10:00.017  08/01/2024 21:10:00.017
# 1  07/06/2024 18:32:15.396  07/06/2024 18:32:15.396
# 2  08/01/2024 20:13:51.563  08/01/2024 20:13:51.563
# 3  08/12/2024 20:15:59.011  08/12/2024 20:15:59.011
# 4  08/01/2024 19:42:52.211  08/01/2024 19:42:52.211
#
#   Autorizacion de Comunicacion             x            y extracted_cedula  \
# 0                          NaN     -75.37413      6.15367              NaN
# 1                     autorizo  -74.91664849   5.86159822              NaN
# 2                          NaN  -75.80066275  6.156059086              NaN
# 3                     autorizo  -74.58196487  6.187416066       43920347.0
# 4                          NaN  -76.62712502  7.904875005              NaN
#
#   Municipio_normalizado       BarrioVereda_normalizado
# 0              rionegro                         capiro
# 1         san francisco                        inojosa
# 2               armenia                      palmichal
# 3           puerto nare  20 enero corregimiento sierra
# 4              apartado                   bajo del oso
#
# [5 rows x 78 columns]

# %% [markdown]
# ## Generación del nuevo dataset

# %%
# Save to a CSV file
output_file = 'combined_data.xlsx'
df_combined.to_excel(output_file, index=False)

print(f"Data combined and saved to {output_file}")
# Out:
# Data combined and saved to combined_data.xlsx
